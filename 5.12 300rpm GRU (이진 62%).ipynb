# %%
# 데이터 시각화
import numpy as np
import pandas as pd
import random
import seaborn as sns
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# 데이터 파일을 읽어옵니다.
normal_data = pd.read_csv("./csv/5000hz/300rpm/300rpm normal data/stream2024_4_22_23_19.csv")
carriage_data = pd.read_csv("./csv/5000hz/300rpm/300rpm carriage damage/stream2024_4_23_2_54.csv")
highspeed_data = pd.read_csv("./csv/5000hz/300rpm/300rpm high-speed damage/stream2024_4_23_0_20.csv")
lack_data = pd.read_csv("./csv/5000hz/300rpm/300rpm lack of lubrication/stream2024_4_23_2_6.csv")
corrosin = pd.read_csv("./csv/5000hz/300rpm/300rpm oxidation and corrosion/stream2024_4_23_1_16.csv")

combined_data = pd.concat([normal_data, carriage_data, highspeed_data, lack_data, corrosin], ignore_index=True)

print(combined_data)

plt.figure(figsize=(15, 5))
plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(normal_data['motor1_y'], label='Y Axis')
#plt.plot(normal_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
plt.plot(combined_data['motor1_y'], label='Y Axis')
#plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['sound'], label='sound')
plt.title('Sound Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
# Out:
#          motor1_x  motor1_y  motor1_z     sound                         time
# 0        0.004470  0.000683 -0.113217 -0.007836  2024-04-22T14:19:00.188683Z
# 1       -0.004681 -0.000264 -0.028029 -0.006258  2024-04-22T14:19:00.188883Z
# 2       -0.007521  0.000683  0.077050 -0.001526  2024-04-22T14:19:00.189083Z
# 3        0.010781  0.000683  0.099140 -0.007836  2024-04-22T14:19:00.189283Z
# 4        0.010465  0.000367 -0.045382 -0.008152  2024-04-22T14:19:00.189483Z
# ...           ...       ...       ...       ...                          ...
# 1499995  0.007941  0.000683 -0.076933 -0.005627  2024-04-22T16:17:00.405099Z
# 1499996 -0.007836  0.000367  0.036657 -0.006574  2024-04-22T16:17:00.405298Z
# 1499997  0.000998  0.000998  0.032555 -0.006574  2024-04-22T16:17:00.405499Z
# 1499998  0.010781  0.000683 -0.084821 -0.007836  2024-04-22T16:17:00.405699Z
# 1499999  0.002261  0.000998  0.025928 -0.005943  2024-04-22T16:17:00.405899Z
#
# [1500000 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import GRU, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# 데이터 파일 로드
normal_data = pd.read_csv("./csv/5000hz/300rpm/300rpm normal data/stream2024_4_22_23_19.csv")
carriage_data = pd.read_csv("./csv/5000hz/300rpm/300rpm carriage damage/stream2024_4_23_2_54.csv")

# 정상 데이터에 레이블 0(정상) 할당, 비정상 데이터에 레이블 1(비정상) 할당
normal_data['label'] = 0
carriage_data['label'] = 1

# 데이터 결합
combined_data = pd.concat([normal_data, carriage_data], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z', 'sound']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=30)

# GRU 입력을 위해 데이터 형태 변경
# (샘플 수, 타임 스텝, 피쳐 수)
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# GRU 모델 생성
model = Sequential()
model.add(GRU(64, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(32))
model.add(Dense(1, activation='sigmoid'))  # 이진 분류 출력 레이어

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Early stopping 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 훈련
history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_test, y_test), callbacks=[early_stopping])

# 모델 서머리
model.summary()

# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Epoch 1/100
# /Users/kimdozz0/Library/Python/3.9/lib/python/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - accuracy: 0.5796 - loss: 0.6657 - val_accuracy: 0.6061 - val_loss: 0.6474
# Epoch 2/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6043 - loss: 0.6487 - val_accuracy: 0.6086 - val_loss: 0.6449
# Epoch 3/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6062 - loss: 0.6465 - val_accuracy: 0.6119 - val_loss: 0.6428
# Epoch 4/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6074 - loss: 0.6447 - val_accuracy: 0.6130 - val_loss: 0.6406
# Epoch 5/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6107 - loss: 0.6432 - val_accuracy: 0.6164 - val_loss: 0.6393
# Epoch 6/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6099 - loss: 0.6423 - val_accuracy: 0.6163 - val_loss: 0.6385
# Epoch 7/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6127 - loss: 0.6403 - val_accuracy: 0.6151 - val_loss: 0.6385
# Epoch 8/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6107 - loss: 0.6405 - val_accuracy: 0.6179 - val_loss: 0.6373
# Epoch 9/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6126 - loss: 0.6394 - val_accuracy: 0.6177 - val_loss: 0.6366
# Epoch 10/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6124 - loss: 0.6401 - val_accuracy: 0.6176 - val_loss: 0.6365
# Epoch 11/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6123 - loss: 0.6389 - val_accuracy: 0.6185 - val_loss: 0.6371
# Epoch 12/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6137 - loss: 0.6387 - val_accuracy: 0.6169 - val_loss: 0.6360
# Epoch 13/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6145 - loss: 0.6379 - val_accuracy: 0.6193 - val_loss: 0.6358
# Epoch 14/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6136 - loss: 0.6387 - val_accuracy: 0.6194 - val_loss: 0.6354
# Epoch 15/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6162 - loss: 0.6372 - val_accuracy: 0.6199 - val_loss: 0.6352
# Epoch 16/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6159 - loss: 0.6370 - val_accuracy: 0.6180 - val_loss: 0.6363
# Epoch 17/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6164 - loss: 0.6369 - val_accuracy: 0.6205 - val_loss: 0.6349
# Epoch 18/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6158 - loss: 0.6370 - val_accuracy: 0.6179 - val_loss: 0.6361
# Epoch 19/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6155 - loss: 0.6374 - val_accuracy: 0.6209 - val_loss: 0.6344
# Epoch 20/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6156 - loss: 0.6375 - val_accuracy: 0.6204 - val_loss: 0.6341
# Epoch 21/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6165 - loss: 0.6361 - val_accuracy: 0.6199 - val_loss: 0.6345
# Epoch 22/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6170 - loss: 0.6364 - val_accuracy: 0.6208 - val_loss: 0.6341
# Epoch 23/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6163 - loss: 0.6362 - val_accuracy: 0.6211 - val_loss: 0.6346
# Epoch 24/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6177 - loss: 0.6368 - val_accuracy: 0.6216 - val_loss: 0.6337
# Epoch 25/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6160 - loss: 0.6363 - val_accuracy: 0.6206 - val_loss: 0.6344
# Epoch 26/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.6158 - loss: 0.6368 - val_accuracy: 0.6220 - val_loss: 0.6337
# Epoch 27/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6170 - loss: 0.6358 - val_accuracy: 0.6210 - val_loss: 0.6342
# Epoch 28/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6171 - loss: 0.6361 - val_accuracy: 0.6210 - val_loss: 0.6340
# Epoch 29/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6169 - loss: 0.6360 - val_accuracy: 0.6220 - val_loss: 0.6337
# Epoch 30/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6170 - loss: 0.6358 - val_accuracy: 0.6215 - val_loss: 0.6336
# Epoch 31/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6179 - loss: 0.6350 - val_accuracy: 0.6236 - val_loss: 0.6336
# Epoch 32/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6177 - loss: 0.6355 - val_accuracy: 0.6229 - val_loss: 0.6335
# Epoch 33/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6183 - loss: 0.6347 - val_accuracy: 0.6214 - val_loss: 0.6339
# Epoch 34/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6185 - loss: 0.6347 - val_accuracy: 0.6229 - val_loss: 0.6332
# Epoch 35/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6189 - loss: 0.6346 - val_accuracy: 0.6220 - val_loss: 0.6333
# Epoch 36/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6186 - loss: 0.6345 - val_accuracy: 0.6220 - val_loss: 0.6335
# Epoch 37/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6175 - loss: 0.6349 - val_accuracy: 0.6229 - val_loss: 0.6330
# Epoch 38/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.6186 - loss: 0.6347 - val_accuracy: 0.6220 - val_loss: 0.6332
# Epoch 39/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6191 - loss: 0.6348 - val_accuracy: 0.6232 - val_loss: 0.6329
# Epoch 40/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6194 - loss: 0.6341 - val_accuracy: 0.6218 - val_loss: 0.6334
# Epoch 41/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.6186 - loss: 0.6353 - val_accuracy: 0.6217 - val_loss: 0.6334
# Epoch 42/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6182 - loss: 0.6345 - val_accuracy: 0.6222 - val_loss: 0.6337
# Epoch 43/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.6186 - loss: 0.6346 - val_accuracy: 0.6231 - val_loss: 0.6327
# Epoch 44/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6184 - loss: 0.6352 - val_accuracy: 0.6230 - val_loss: 0.6329
# Epoch 45/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6198 - loss: 0.6343 - val_accuracy: 0.6219 - val_loss: 0.6329
# Epoch 46/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6175 - loss: 0.6348 - val_accuracy: 0.6229 - val_loss: 0.6330
# Epoch 47/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6199 - loss: 0.6340 - val_accuracy: 0.6233 - val_loss: 0.6328
# Epoch 48/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.6195 - loss: 0.6339 - val_accuracy: 0.6215 - val_loss: 0.6328
# Epoch 49/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.6185 - loss: 0.6344 - val_accuracy: 0.6236 - val_loss: 0.6324
# Epoch 50/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6189 - loss: 0.6337 - val_accuracy: 0.6229 - val_loss: 0.6329
# Epoch 51/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6189 - loss: 0.6345 - val_accuracy: 0.6222 - val_loss: 0.6327
# Epoch 52/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6202 - loss: 0.6339 - val_accuracy: 0.6226 - val_loss: 0.6324
# Epoch 53/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.6202 - loss: 0.6342 - val_accuracy: 0.6236 - val_loss: 0.6326
# Epoch 54/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.6188 - loss: 0.6344 - val_accuracy: 0.6225 - val_loss: 0.6324
# Epoch 55/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6189 - loss: 0.6344 - val_accuracy: 0.6236 - val_loss: 0.6323
# Epoch 56/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6193 - loss: 0.6342 - val_accuracy: 0.6224 - val_loss: 0.6326
# Epoch 57/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6190 - loss: 0.6346 - val_accuracy: 0.6233 - val_loss: 0.6324
# Epoch 58/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6195 - loss: 0.6341 - val_accuracy: 0.6230 - val_loss: 0.6325
# Epoch 59/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6187 - loss: 0.6341 - val_accuracy: 0.6227 - val_loss: 0.6326
# Epoch 60/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6186 - loss: 0.6347 - val_accuracy: 0.6233 - val_loss: 0.6323
# Epoch 61/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6192 - loss: 0.6337 - val_accuracy: 0.6226 - val_loss: 0.6325
# Epoch 62/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6193 - loss: 0.6336 - val_accuracy: 0.6231 - val_loss: 0.6326
# Epoch 63/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.6183 - loss: 0.6337 - val_accuracy: 0.6225 - val_loss: 0.6327
# Epoch 64/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6207 - loss: 0.6335 - val_accuracy: 0.6227 - val_loss: 0.6321
# Epoch 65/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6203 - loss: 0.6334 - val_accuracy: 0.6233 - val_loss: 0.6323
# Epoch 66/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6202 - loss: 0.6334 - val_accuracy: 0.6240 - val_loss: 0.6320
# Epoch 67/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6192 - loss: 0.6338 - val_accuracy: 0.6235 - val_loss: 0.6322
# Epoch 68/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.6199 - loss: 0.6337 - val_accuracy: 0.6235 - val_loss: 0.6322
# Epoch 69/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6201 - loss: 0.6340 - val_accuracy: 0.6231 - val_loss: 0.6321
# Epoch 70/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6194 - loss: 0.6338 - val_accuracy: 0.6244 - val_loss: 0.6320
# Epoch 71/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6197 - loss: 0.6336 - val_accuracy: 0.6243 - val_loss: 0.6320
# Epoch 72/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6195 - loss: 0.6338 - val_accuracy: 0.6227 - val_loss: 0.6322
# Epoch 73/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6194 - loss: 0.6341 - val_accuracy: 0.6242 - val_loss: 0.6317
# Epoch 74/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6207 - loss: 0.6324 - val_accuracy: 0.6240 - val_loss: 0.6319
# Epoch 75/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6201 - loss: 0.6332 - val_accuracy: 0.6229 - val_loss: 0.6321
# Epoch 76/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6193 - loss: 0.6333 - val_accuracy: 0.6245 - val_loss: 0.6317
# Epoch 77/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6203 - loss: 0.6335 - val_accuracy: 0.6230 - val_loss: 0.6324
# Epoch 78/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6207 - loss: 0.6340 - val_accuracy: 0.6236 - val_loss: 0.6319
# Epoch 79/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6201 - loss: 0.6331 - val_accuracy: 0.6237 - val_loss: 0.6317
# Epoch 80/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6190 - loss: 0.6343 - val_accuracy: 0.6240 - val_loss: 0.6317
# Epoch 81/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6188 - loss: 0.6337 - val_accuracy: 0.6219 - val_loss: 0.6321
# Epoch 82/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6204 - loss: 0.6339 - val_accuracy: 0.6225 - val_loss: 0.6319
# Epoch 83/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6200 - loss: 0.6336 - val_accuracy: 0.6236 - val_loss: 0.6317
# Epoch 84/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6207 - loss: 0.6329 - val_accuracy: 0.6247 - val_loss: 0.6317
# Epoch 85/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6193 - loss: 0.6334 - val_accuracy: 0.6238 - val_loss: 0.6318
# Epoch 86/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6195 - loss: 0.6338 - val_accuracy: 0.6234 - val_loss: 0.6318
# Epoch 87/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6201 - loss: 0.6335 - val_accuracy: 0.6227 - val_loss: 0.6319
# Epoch 88/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6197 - loss: 0.6337 - val_accuracy: 0.6232 - val_loss: 0.6319
# Epoch 89/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6202 - loss: 0.6336 - val_accuracy: 0.6216 - val_loss: 0.6324
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 1, 64)          │        13,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,645 (268.15 KB)
#  Trainable params: 22,881 (89.38 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 45,764 (178.77 KB)
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 2s 490us/step - accuracy: 0.6245 - loss: 0.6320
# Test Loss: 0.6316928267478943
# Test Accuracy: 0.6236833333969116
