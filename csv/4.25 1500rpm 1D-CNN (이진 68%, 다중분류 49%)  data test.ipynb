# %%
cd C:/Users/7-2009-1186-16/Desktop/-sampling-frequency-hz-/csv/5000hz/1500rpm
# Out:
# C:\Users\7-2009-1186-16\Desktop\-sampling-frequency-hz-\csv\5000hz\1500rpm

# %%
import pandas as pd

# 데이터 파일을 읽어옵니다.
normal_data = pd.read_csv("1500rpm normal data/stream2024_4_22_23_51.csv")
carriage_data = pd.read_csv("1500rpm carriage damage/stream2024_4_23_3_17.csv")
highspeed_data = pd.read_csv("1500rpm high-speed damage/stream2024_4_23_0_41.csv")
lack_data = pd.read_csv("1500rpm lack of lubrication/stream2024_4_23_2_29.csv")
corrosin = pd.read_csv("1500rpm oxidation and corrosion/stream2024_4_23_1_38.csv")

# 데이터의 처음 몇 개 행을 확인하여 구조를 파악합니다.
print(carriage_data.head())

# 데이터 결측값 확인
missing_values = corrosin.isnull().sum()
print(missing_values)
# Out:
#    motor1_x  motor1_y  motor1_z     sound                         time
# 0 -0.018248  0.000683  0.177084 -0.006574  2024-04-22T18:17:00.328450Z
# 1  0.017723  0.000998 -0.100281 -0.016039  2024-04-22T18:17:00.328650Z
# 2  0.009834  0.000052  0.017723 -0.008467  2024-04-22T18:17:00.328850Z
# 3 -0.006574  0.000683 -0.074724 -0.009414  2024-04-22T18:17:00.329050Z
# 4 -0.018879  0.000683  0.139217 -0.008467  2024-04-22T18:17:00.329250Z
# motor1_x    0
# motor1_y    0
# motor1_z    0
# sound       0
# time        0
# dtype: int64

# %%
# 데이터 시각화
import numpy as np
import pandas as pd
import random
import seaborn as sns
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# 데이터 파일을 읽어옵니다.
normal_data = pd.read_csv("1500rpm normal data/stream2024_4_22_23_51.csv")
carriage_data = pd.read_csv("1500rpm carriage damage/stream2024_4_23_3_17.csv")
highspeed_data = pd.read_csv("1500rpm high-speed damage/stream2024_4_23_0_41.csv")
lack_data = pd.read_csv("1500rpm lack of lubrication/stream2024_4_23_2_29.csv")
corrosin = pd.read_csv("1500rpm oxidation and corrosion/stream2024_4_23_1_38.csv")

combined_data = pd.concat([normal_data, carriage_data, highspeed_data, lack_data, corrosin], ignore_index=True)

print(combined_data)

plt.figure(figsize=(15, 5))
plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(normal_data['motor1_y'], label='Y Axis')
#plt.plot(normal_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
plt.plot(combined_data['motor1_y'], label='Y Axis')
#plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['sound'], label='sound')
plt.title('Sound Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
# Out:
#          motor1_x  motor1_y  motor1_z     sound                         time
# 0        0.001630  0.000683 -0.132148 -0.007836  2024-04-22T14:51:00.170282Z
# 1       -0.005943  0.000998 -0.000579 -0.011938  2024-04-22T14:51:00.170482Z
# 2       -0.008783  0.000998  0.032871 -0.008152  2024-04-22T14:51:00.170682Z
# 3        0.002892  0.000683  0.190654 -0.008467  2024-04-22T14:51:00.170882Z
# 4        0.000998  0.000683  0.014252 -0.006574  2024-04-22T14:51:00.171082Z
# ...           ...       ...       ...       ...                          ...
# 1499995  0.074841  0.000683  0.042653 -0.008152  2024-04-22T16:39:00.039091Z
# 1499996 -0.016670  0.000367  1.700323 -0.007521  2024-04-22T16:39:00.039291Z
# 1499997  0.072316  0.000998 -1.277769 -0.007521  2024-04-22T16:39:00.039491Z
# 1499998  0.069161  0.000683 -0.270973 -0.006889  2024-04-22T16:39:00.039691Z
# 1499999  0.139848  0.000367  0.031608 -0.006889  2024-04-22T16:39:00.039891Z
#
# [1500000 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# 데이터 파일 로드
normal_data = pd.read_csv("1500rpm normal data/stream2024_4_22_23_51.csv")
carriage_data = pd.read_csv("1500rpm carriage damage/stream2024_4_23_3_17.csv")

# 정상 데이터에 레이블 0(정상) 할당, 비정상 데이터에 레이블 1(비정상) 할당
normal_data['label'] = 0
carriage_data['label'] = 1

# 데이터 결합
combined_data = pd.concat([normal_data, carriage_data], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z', 'sound']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=30)

# 1D CNN 입력을 위해 데이터 형태 변경
# (샘플 수, 시퀀스 길이, 채널 수)
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# CNN 모델 생성
model = Sequential()
model.add(Conv1D(64, kernel_size=4, activation='relu', input_shape=(X_train.shape[1], 1), padding='same'))
model.add(MaxPooling1D(pool_size=1))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))  # 이진 분류 출력 레이어

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Early stopping 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 훈련
history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_test, y_test), callbacks=[early_stopping])

# 모델 서머리
model.summary()

# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Epoch 1/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5750 - accuracy: 0.6768 - val_loss: 0.5688 - val_accuracy: 0.6826
# Epoch 2/100
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.5693 - accuracy: 0.6813 - val_loss: 0.5679 - val_accuracy: 0.6821
# Epoch 3/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5681 - accuracy: 0.6828 - val_loss: 0.5661 - val_accuracy: 0.6842
# Epoch 4/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5672 - accuracy: 0.6833 - val_loss: 0.5655 - val_accuracy: 0.6849
# Epoch 5/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5668 - accuracy: 0.6837 - val_loss: 0.5662 - val_accuracy: 0.6842
# Epoch 6/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5659 - accuracy: 0.6841 - val_loss: 0.5635 - val_accuracy: 0.6867
# Epoch 7/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5653 - accuracy: 0.6846 - val_loss: 0.5640 - val_accuracy: 0.6861
# Epoch 8/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5651 - accuracy: 0.6848 - val_loss: 0.5631 - val_accuracy: 0.6866
# Epoch 9/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5648 - accuracy: 0.6852 - val_loss: 0.5628 - val_accuracy: 0.6872
# Epoch 10/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5643 - accuracy: 0.6855 - val_loss: 0.5627 - val_accuracy: 0.6866
# Epoch 11/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5644 - accuracy: 0.6859 - val_loss: 0.5629 - val_accuracy: 0.6866
# Epoch 12/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5643 - accuracy: 0.6858 - val_loss: 0.5627 - val_accuracy: 0.6871
# Epoch 13/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5640 - accuracy: 0.6862 - val_loss: 0.5630 - val_accuracy: 0.6870
# Epoch 14/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5638 - accuracy: 0.6864 - val_loss: 0.5622 - val_accuracy: 0.6876
# Epoch 15/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5635 - accuracy: 0.6863 - val_loss: 0.5621 - val_accuracy: 0.6876
# Epoch 16/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5636 - accuracy: 0.6864 - val_loss: 0.5616 - val_accuracy: 0.6883
# Epoch 17/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5635 - accuracy: 0.6864 - val_loss: 0.5614 - val_accuracy: 0.6888
# Epoch 18/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5633 - accuracy: 0.6861 - val_loss: 0.5630 - val_accuracy: 0.6869
# Epoch 19/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5633 - accuracy: 0.6866 - val_loss: 0.5625 - val_accuracy: 0.6880
# Epoch 20/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5630 - accuracy: 0.6867 - val_loss: 0.5619 - val_accuracy: 0.6891
# Epoch 21/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5631 - accuracy: 0.6866 - val_loss: 0.5620 - val_accuracy: 0.6878
# Epoch 22/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5629 - accuracy: 0.6874 - val_loss: 0.5620 - val_accuracy: 0.6879
# Epoch 23/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5628 - accuracy: 0.6868 - val_loss: 0.5612 - val_accuracy: 0.6881
# Epoch 24/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5629 - accuracy: 0.6873 - val_loss: 0.5607 - val_accuracy: 0.6887
# Epoch 25/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5628 - accuracy: 0.6869 - val_loss: 0.5621 - val_accuracy: 0.6875
# Epoch 26/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5628 - accuracy: 0.6867 - val_loss: 0.5611 - val_accuracy: 0.6885
# Epoch 27/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5628 - accuracy: 0.6871 - val_loss: 0.5610 - val_accuracy: 0.6884
# Epoch 28/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5626 - accuracy: 0.6873 - val_loss: 0.5610 - val_accuracy: 0.6892
# Epoch 29/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5627 - accuracy: 0.6868 - val_loss: 0.5609 - val_accuracy: 0.6889
# Epoch 30/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5622 - accuracy: 0.6874 - val_loss: 0.5613 - val_accuracy: 0.6880
# Epoch 31/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.5624 - accuracy: 0.6873 - val_loss: 0.5610 - val_accuracy: 0.6889
# Epoch 32/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5623 - accuracy: 0.6876 - val_loss: 0.5608 - val_accuracy: 0.6888
# Epoch 33/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5624 - accuracy: 0.6869 - val_loss: 0.5608 - val_accuracy: 0.6897
# Epoch 34/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.5622 - accuracy: 0.6874 - val_loss: 0.5609 - val_accuracy: 0.6888
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 4, 64)             320
#
#  max_pooling1d (MaxPooling1D  (None, 4, 64)            0
#  )
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 50)                12850
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 13,221
# Trainable params: 13,221
# Non-trainable params: 0
# _________________________________________________________________
# 3750/3750 [==============================] - 4s 1ms/step - loss: 0.5607 - accuracy: 0.6887
# Test Loss: 0.5607023239135742
# Test Accuracy: 0.6887166500091553

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import tensorflow as tf
import matplotlib.pyplot as plt

# GPU 설정
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) == 0:
    print("GPU가 없거나 설정되지 않았습니다. CPU로 계속 진행합니다.")
else:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# 데이터 파일 로드
# 각 고장 유형에 대한 데이터가 다른 폴더에 위치하는 경우를 가정
# 각 폴더에서 데이터를 로드하고 레이블을 할당한 후 데이터 결합
normal_data = pd.read_csv("1500rpm normal data/stream2024_4_22_23_51.csv")
carriage_data = pd.read_csv("1500rpm carriage damage/stream2024_4_23_3_17.csv")
highspeed_data = pd.read_csv("1500rpm high-speed damage/stream2024_4_23_0_41.csv")
lack_data = pd.read_csv("1500rpm lack of lubrication/stream2024_4_23_2_29.csv")
corrosin = pd.read_csv("1500rpm oxidation and corrosion/stream2024_4_23_1_38.csv")


# 정상 데이터에 레이블 0(정상) 할당
normal_data['label'] = 'normal'

# 각 고장 유형에 대한 데이터를 로드하고 해당 레이블 할당
carriage_data['label'] = 'carriage_data'
highspeed_data['label'] = 'highspeed_data'
lack_data['label'] = 'lack_data'
corrosin['label'] = 'corrosin'

# 데이터 결합
combined_data = pd.concat([normal_data, carriage_data, highspeed_data, lack_data, corrosin], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z', 'sound']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 레이블 인코딩
encoder = LabelEncoder()
y = encoder.fit_transform(labels)
y = np_utils.to_categorical(y)  # 원-핫 인코딩

# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# 1D CNN 입력을 위해 데이터 형태 변경
# (샘플 수, 시퀀스 길이, 채널 수)
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# 모델 생성
model = Sequential()
model.add(Conv1D(64, kernel_size=4, activation='relu', input_shape=(X_train.shape[1], 1), padding='same'))
model.add(MaxPooling1D(pool_size=1))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5, activation='softmax'))  # 다중 클래스 분류

# 모델 컴파일
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Early stopping 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 훈련
history = model.fit(X_train, y_train, epochs=100, batch_size=256, validation_data=(X_test, y_test), callbacks=[early_stopping])



# 모델 서머리
model.summary()

# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# GPU가 없거나 설정되지 않았습니다. CPU로 계속 진행합니다.
# Epoch 1/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.0692 - accuracy: 0.4754 - val_loss: 1.0559 - val_accuracy: 0.4835
# Epoch 2/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.0567 - accuracy: 0.4824 - val_loss: 1.0509 - val_accuracy: 0.4867
# Epoch 3/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.0547 - accuracy: 0.4846 - val_loss: 1.0503 - val_accuracy: 0.4895
# Epoch 4/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.0538 - accuracy: 0.4852 - val_loss: 1.0498 - val_accuracy: 0.4897
# Epoch 5/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.0532 - accuracy: 0.4859 - val_loss: 1.0486 - val_accuracy: 0.4901
# Epoch 6/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.0525 - accuracy: 0.4868 - val_loss: 1.0481 - val_accuracy: 0.4903
# Epoch 7/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.0519 - accuracy: 0.4866 - val_loss: 1.0474 - val_accuracy: 0.4908
# Epoch 8/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.0517 - accuracy: 0.4866 - val_loss: 1.0491 - val_accuracy: 0.4907
# Epoch 9/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0513 - accuracy: 0.4872 - val_loss: 1.0499 - val_accuracy: 0.4902
# Epoch 10/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.0512 - accuracy: 0.4877 - val_loss: 1.0491 - val_accuracy: 0.4900
# Epoch 11/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0506 - accuracy: 0.4877 - val_loss: 1.0477 - val_accuracy: 0.4901
# Epoch 12/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0505 - accuracy: 0.4882 - val_loss: 1.0465 - val_accuracy: 0.4922
# Epoch 13/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0501 - accuracy: 0.4882 - val_loss: 1.0478 - val_accuracy: 0.4902
# Epoch 14/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0502 - accuracy: 0.4883 - val_loss: 1.0472 - val_accuracy: 0.4898
# Epoch 15/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0498 - accuracy: 0.4884 - val_loss: 1.0464 - val_accuracy: 0.4918
# Epoch 16/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0499 - accuracy: 0.4888 - val_loss: 1.0465 - val_accuracy: 0.4919
# Epoch 17/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0498 - accuracy: 0.4888 - val_loss: 1.0468 - val_accuracy: 0.4933
# Epoch 18/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0495 - accuracy: 0.4891 - val_loss: 1.0469 - val_accuracy: 0.4914
# Epoch 19/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0494 - accuracy: 0.4891 - val_loss: 1.0464 - val_accuracy: 0.4917
# Epoch 20/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0493 - accuracy: 0.4892 - val_loss: 1.0473 - val_accuracy: 0.4922
# Epoch 21/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0493 - accuracy: 0.4892 - val_loss: 1.0475 - val_accuracy: 0.4917
# Epoch 22/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0490 - accuracy: 0.4896 - val_loss: 1.0458 - val_accuracy: 0.4929
# Epoch 23/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0489 - accuracy: 0.4898 - val_loss: 1.0458 - val_accuracy: 0.4923
# Epoch 24/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0491 - accuracy: 0.4896 - val_loss: 1.0460 - val_accuracy: 0.4916
# Epoch 25/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0488 - accuracy: 0.4896 - val_loss: 1.0463 - val_accuracy: 0.4927
# Epoch 26/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0488 - accuracy: 0.4897 - val_loss: 1.0467 - val_accuracy: 0.4920
# Epoch 27/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0487 - accuracy: 0.4899 - val_loss: 1.0461 - val_accuracy: 0.4924
# Epoch 28/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0488 - accuracy: 0.4900 - val_loss: 1.0450 - val_accuracy: 0.4934
# Epoch 29/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0486 - accuracy: 0.4900 - val_loss: 1.0470 - val_accuracy: 0.4921
# Epoch 30/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0485 - accuracy: 0.4901 - val_loss: 1.0467 - val_accuracy: 0.4915
# Epoch 31/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.0485 - accuracy: 0.4900 - val_loss: 1.0453 - val_accuracy: 0.4934
# Epoch 32/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0485 - accuracy: 0.4902 - val_loss: 1.0451 - val_accuracy: 0.4938
# Epoch 33/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.0483 - accuracy: 0.4905 - val_loss: 1.0469 - val_accuracy: 0.4928
# Epoch 34/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.0482 - accuracy: 0.4901 - val_loss: 1.0451 - val_accuracy: 0.4936
# Epoch 35/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.0481 - accuracy: 0.4904 - val_loss: 1.0455 - val_accuracy: 0.4931
# Epoch 36/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.0481 - accuracy: 0.4901 - val_loss: 1.0464 - val_accuracy: 0.4933
# Epoch 37/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.0479 - accuracy: 0.4907 - val_loss: 1.0452 - val_accuracy: 0.4937
# Epoch 38/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.0479 - accuracy: 0.4904 - val_loss: 1.0457 - val_accuracy: 0.4937
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 4, 64)             320
#
#  max_pooling1d_1 (MaxPooling  (None, 4, 64)            0
#  1D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 33,861
# Trainable params: 33,861
# Non-trainable params: 0
# _________________________________________________________________
# 9375/9375 [==============================] - 11s 1ms/step - loss: 1.0450 - accuracy: 0.4934
# Test Loss: 1.0450189113616943
# Test Accuracy: 0.4934333264827728
