# %%
cd C:/Users/7-2009-1186-16/Desktop/-sampling-frequency-hz-/csv/5000hz/3000rpm
# Out:
# C:\Users\7-2009-1186-16\Desktop\-sampling-frequency-hz-\csv\5000hz\3000rpm

# %%
import pandas as pd

# 데이터 파일을 읽어옵니다.
normal_data = pd.read_csv("3000rpm normal data/stream2024_4_23_0_2.csv")
carriage_data = pd.read_csv("3000rpm carriage damage/stream2024_4_23_3_30.csv")
highspeed_data = pd.read_csv("3000rpm high-speed damage/stream2024_4_23_0_57.csv")
lack_data = pd.read_csv("3000rpm lack of lubrication/stream2024_4_23_2_40.csv")
corrosin = pd.read_csv("3000rpm oxidation and corrosion/stream2024_4_23_1_50.csv")

# 데이터의 처음 몇 개 행을 확인하여 구조를 파악합니다.
print(carriage_data.head())

# 데이터 결측값 확인
missing_values = corrosin.isnull().sum()
print(missing_values)
# Out:
#    motor1_x  motor1_y  motor1_z     sound                         time
# 0 -0.020772  0.000367 -0.000895 -0.005943  2024-04-22T18:30:00.290359Z
# 1  0.068530  0.000998 -0.197774 -0.007205  2024-04-22T18:30:00.290559Z
# 2 -0.132148  0.000998  0.982410 -0.001841  2024-04-22T18:30:00.290759Z
# 3  0.019617  0.000367 -0.213234 -0.006574  2024-04-22T18:30:00.290958Z
# 4  0.185605  0.000683 -0.100596 -0.006574  2024-04-22T18:30:00.291158Z
# motor1_x    0
# motor1_y    0
# motor1_z    0
# sound       0
# time        0
# dtype: int64

# %%
# 데이터 시각화
import numpy as np
import pandas as pd
import random
import seaborn as sns
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# 데이터 파일을 읽어옵니다.
normal_data = pd.read_csv("3000rpm normal data/stream2024_4_23_0_2.csv")
carriage_data = pd.read_csv("3000rpm carriage damage/stream2024_4_23_3_30.csv")
highspeed_data = pd.read_csv("3000rpm high-speed damage/stream2024_4_23_0_57.csv")
lack_data = pd.read_csv("3000rpm lack of lubrication/stream2024_4_23_2_40.csv")
corrosin = pd.read_csv("3000rpm oxidation and corrosion/stream2024_4_23_1_50.csv")

combined_data = pd.concat([normal_data, carriage_data, highspeed_data, lack_data, corrosin], ignore_index=True)

print(combined_data)

plt.figure(figsize=(15, 5))
plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(normal_data['motor1_y'], label='Y Axis')
#plt.plot(normal_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
plt.plot(combined_data['motor1_y'], label='Y Axis')
#plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['sound'], label='sound')
plt.title('Sound Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
# Out:
#          motor1_x  motor1_y  motor1_z     sound                         time
# 0       -0.029922  0.000998 -0.146661  0.000052  2024-04-22T15:02:00.072005Z
# 1        0.014883  0.000998  0.106713 -0.006574  2024-04-22T15:02:00.072205Z
# 2        0.022141  0.000367 -0.142875 -0.007836  2024-04-22T15:02:00.072405Z
# 3       -0.001210  0.000683 -0.070307 -0.006574  2024-04-22T15:02:00.072605Z
# 4        0.004154  0.000683 -0.086398 -0.009098  2024-04-22T15:02:00.072805Z
# ...           ...       ...       ...       ...                          ...
# 1499995  0.055276  0.000683 -1.020628 -0.011938  2024-04-22T16:51:00.210862Z
# 1499996  0.061903  0.000998 -0.274443 -0.005312  2024-04-22T16:51:00.211061Z
# 1499997  0.179925  0.000998 -2.924108 -0.011938  2024-04-22T16:51:00.211262Z
# 1499998 -0.039072  0.000367 -0.361524 -0.006258  2024-04-22T16:51:00.211462Z
# 1499999 -0.252673  0.000367  7.789491 -0.007836  2024-04-22T16:51:00.211662Z
#
# [1500000 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# 데이터 파일 로드
normal_data = pd.read_csv("3000rpm normal data/stream2024_4_23_0_2.csv")
carriage_data = pd.read_csv("3000rpm carriage damage/stream2024_4_23_3_30.csv")
highspeed_data = pd.read_csv("3000rpm high-speed damage/stream2024_4_23_0_57.csv")
lack_data = pd.read_csv("3000rpm lack of lubrication/stream2024_4_23_2_40.csv")
corrosin = pd.read_csv("3000rpm oxidation and corrosion/stream2024_4_23_1_50.csv")

# 정상 데이터에 레이블 0(정상) 할당, 비정상 데이터에 레이블 1(비정상) 할당
normal_data['label'] = 0
carriage_data['label'] = 1
#highspeed_data['label'] = 1
#lack_data['label'] = 1
#corrosin['label'] = 1

# 데이터 결합
combined_data = pd.concat([normal_data, carriage_data], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z', 'sound']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=30)

# 1D CNN 입력을 위해 데이터 형태 변경
# (샘플 수, 시퀀스 길이, 채널 수)
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# CNN 모델 생성
model = Sequential()
model.add(Conv1D(64, kernel_size=2, activation='relu', input_shape=(X_train.shape[1], 1), padding='same'))
model.add(MaxPooling1D(pool_size=1))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))  # 이진 분류 출력 레이어

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Early stopping 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 훈련
history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_test, y_test), callbacks=[early_stopping])

# 모델 서머리
model.summary()

# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Epoch 1/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4448 - accuracy: 0.7886 - val_loss: 0.4357 - val_accuracy: 0.7938
# Epoch 2/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.4385 - accuracy: 0.7918 - val_loss: 0.4343 - val_accuracy: 0.7941
# Epoch 3/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4374 - accuracy: 0.7926 - val_loss: 0.4345 - val_accuracy: 0.7943
# Epoch 4/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.4371 - accuracy: 0.7927 - val_loss: 0.4337 - val_accuracy: 0.7943
# Epoch 5/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.4365 - accuracy: 0.7931 - val_loss: 0.4339 - val_accuracy: 0.7942
# Epoch 6/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.4363 - accuracy: 0.7933 - val_loss: 0.4337 - val_accuracy: 0.7948
# Epoch 7/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4360 - accuracy: 0.7932 - val_loss: 0.4334 - val_accuracy: 0.7948
# Epoch 8/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.4359 - accuracy: 0.7932 - val_loss: 0.4332 - val_accuracy: 0.7947
# Epoch 9/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.4359 - accuracy: 0.7935 - val_loss: 0.4328 - val_accuracy: 0.7951
# Epoch 10/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.4356 - accuracy: 0.7935 - val_loss: 0.4335 - val_accuracy: 0.7944
# Epoch 11/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4357 - accuracy: 0.7936 - val_loss: 0.4332 - val_accuracy: 0.7949
# Epoch 12/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.4355 - accuracy: 0.7934 - val_loss: 0.4332 - val_accuracy: 0.7948
# Epoch 13/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4354 - accuracy: 0.7936 - val_loss: 0.4328 - val_accuracy: 0.7952
# Epoch 14/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4353 - accuracy: 0.7935 - val_loss: 0.4338 - val_accuracy: 0.7944
# Epoch 15/100
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.4354 - accuracy: 0.7935 - val_loss: 0.4336 - val_accuracy: 0.7950
# Epoch 16/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4352 - accuracy: 0.7938 - val_loss: 0.4333 - val_accuracy: 0.7949
# Epoch 17/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4353 - accuracy: 0.7930 - val_loss: 0.4329 - val_accuracy: 0.7950
# Epoch 18/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4352 - accuracy: 0.7938 - val_loss: 0.4329 - val_accuracy: 0.7955
# Epoch 19/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4351 - accuracy: 0.7941 - val_loss: 0.4324 - val_accuracy: 0.7956
# Epoch 20/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4352 - accuracy: 0.7939 - val_loss: 0.4329 - val_accuracy: 0.7946
# Epoch 21/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4350 - accuracy: 0.7937 - val_loss: 0.4325 - val_accuracy: 0.7951
# Epoch 22/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4350 - accuracy: 0.7940 - val_loss: 0.4325 - val_accuracy: 0.7952
# Epoch 23/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4350 - accuracy: 0.7940 - val_loss: 0.4325 - val_accuracy: 0.7951
# Epoch 24/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4349 - accuracy: 0.7938 - val_loss: 0.4325 - val_accuracy: 0.7955
# Epoch 25/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4348 - accuracy: 0.7939 - val_loss: 0.4338 - val_accuracy: 0.7944
# Epoch 26/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4349 - accuracy: 0.7939 - val_loss: 0.4323 - val_accuracy: 0.7955
# Epoch 27/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4349 - accuracy: 0.7940 - val_loss: 0.4327 - val_accuracy: 0.7955
# Epoch 28/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4348 - accuracy: 0.7940 - val_loss: 0.4327 - val_accuracy: 0.7951
# Epoch 29/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4350 - accuracy: 0.7939 - val_loss: 0.4323 - val_accuracy: 0.7954
# Epoch 30/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4349 - accuracy: 0.7940 - val_loss: 0.4330 - val_accuracy: 0.7951
# Epoch 31/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4349 - accuracy: 0.7940 - val_loss: 0.4331 - val_accuracy: 0.7946
# Epoch 32/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4350 - accuracy: 0.7941 - val_loss: 0.4337 - val_accuracy: 0.7942
# Epoch 33/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4348 - accuracy: 0.7940 - val_loss: 0.4333 - val_accuracy: 0.7953
# Epoch 34/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4346 - accuracy: 0.7941 - val_loss: 0.4329 - val_accuracy: 0.7953
# Epoch 35/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.4350 - accuracy: 0.7942 - val_loss: 0.4325 - val_accuracy: 0.7947
# Epoch 36/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.4349 - accuracy: 0.7941 - val_loss: 0.4331 - val_accuracy: 0.7954
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_14 (Conv1D)          (None, 4, 64)             192
#
#  max_pooling1d_14 (MaxPoolin  (None, 4, 64)            0
#  g1D)
#
#  flatten_14 (Flatten)        (None, 256)               0
#
#  dense_28 (Dense)            (None, 50)                12850
#
#  dropout_14 (Dropout)        (None, 50)                0
#
#  dense_29 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 13,093
# Trainable params: 13,093
# Non-trainable params: 0
# _________________________________________________________________
# 3750/3750 [==============================] - 4s 1ms/step - loss: 0.4323 - accuracy: 0.7955
# Test Loss: 0.4322967529296875
# Test Accuracy: 0.7955416440963745

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import tensorflow as tf
import matplotlib.pyplot as plt

# GPU 설정
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) == 0:
    print("GPU가 없거나 설정되지 않았습니다. CPU로 계속 진행합니다.")
else:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# 데이터 파일 로드
# 각 고장 유형에 대한 데이터가 다른 폴더에 위치하는 경우를 가정
# 각 폴더에서 데이터를 로드하고 레이블을 할당한 후 데이터 결합
normal_data = pd.read_csv("3000rpm normal data/stream2024_4_23_0_2.csv")
carriage_data = pd.read_csv("3000rpm carriage damage/stream2024_4_23_3_30.csv")
highspeed_data = pd.read_csv("3000rpm high-speed damage/stream2024_4_23_0_57.csv")
lack_data = pd.read_csv("3000rpm lack of lubrication/stream2024_4_23_2_40.csv")
corrosin = pd.read_csv("3000rpm oxidation and corrosion/stream2024_4_23_1_50.csv")


# 정상 데이터에 레이블 0(정상) 할당
normal_data['label'] = 'normal'

# 각 고장 유형에 대한 데이터를 로드하고 해당 레이블 할당
carriage_data['label'] = 'carriage_data'
highspeed_data['label'] = 'highspeed_data'
lack_data['label'] = 'lack_data'
corrosin['label'] = 'corrosin'

# 데이터 결합
combined_data = pd.concat([normal_data, carriage_data, highspeed_data, lack_data, corrosin], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 레이블 인코딩
encoder = LabelEncoder()
y = encoder.fit_transform(labels)
y = np_utils.to_categorical(y)  # 원-핫 인코딩

# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# 1D CNN 입력을 위해 데이터 형태 변경
# (샘플 수, 시퀀스 길이, 채널 수)
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# 모델 생성
model = Sequential()
model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1), padding='same'))
model.add(MaxPooling1D(pool_size=1))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5, activation='softmax'))  # 다중 클래스 분류

# 모델 컴파일
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Early stopping 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 훈련
history = model.fit(X_train, y_train, epochs=100, batch_size=256, validation_data=(X_test, y_test), callbacks=[early_stopping])



# 모델 서머리
model.summary()

# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# GPU가 없거나 설정되지 않았습니다. CPU로 계속 진행합니다.
# Epoch 1/100
# 4688/4688 [==============================] - 22s 5ms/step - loss: 1.0636 - accuracy: 0.4850 - val_loss: 1.0514 - val_accuracy: 0.4879
# Epoch 2/100
# 4688/4688 [==============================] - 21s 4ms/step - loss: 1.0518 - accuracy: 0.4899 - val_loss: 1.0473 - val_accuracy: 0.4910
# Epoch 3/100
# 4688/4688 [==============================] - 20s 4ms/step - loss: 1.0510 - accuracy: 0.4906 - val_loss: 1.0493 - val_accuracy: 0.4875
# Epoch 4/100
# 4688/4688 [==============================] - 20s 4ms/step - loss: 1.0504 - accuracy: 0.4910 - val_loss: 1.0461 - val_accuracy: 0.4931
# Epoch 5/100
# 4688/4688 [==============================] - 21s 4ms/step - loss: 1.0499 - accuracy: 0.4909 - val_loss: 1.0464 - val_accuracy: 0.4923
# Epoch 6/100
# 4688/4688 [==============================] - 22s 5ms/step - loss: 1.0495 - accuracy: 0.4915 - val_loss: 1.0457 - val_accuracy: 0.4931
# Epoch 7/100
# 4688/4688 [==============================] - 20s 4ms/step - loss: 1.0493 - accuracy: 0.4915 - val_loss: 1.0457 - val_accuracy: 0.4936
# Epoch 8/100
# 4688/4688 [==============================] - 20s 4ms/step - loss: 1.0490 - accuracy: 0.4919 - val_loss: 1.0462 - val_accuracy: 0.4939
# Epoch 9/100
# 4688/4688 [==============================] - 20s 4ms/step - loss: 1.0489 - accuracy: 0.4917 - val_loss: 1.0465 - val_accuracy: 0.4928
# Epoch 10/100
# 4688/4688 [==============================] - 20s 4ms/step - loss: 1.0488 - accuracy: 0.4917 - val_loss: 1.0464 - val_accuracy: 0.4944
# Epoch 11/100
# 4688/4688 [==============================] - 23s 5ms/step - loss: 1.0485 - accuracy: 0.4921 - val_loss: 1.0446 - val_accuracy: 0.4947
# Epoch 12/100
# 4688/4688 [==============================] - 21s 5ms/step - loss: 1.0484 - accuracy: 0.4923 - val_loss: 1.0455 - val_accuracy: 0.4942
# Epoch 13/100
# 4688/4688 [==============================] - 23s 5ms/step - loss: 1.0483 - accuracy: 0.4919 - val_loss: 1.0466 - val_accuracy: 0.4912
# Epoch 14/100
# 4688/4688 [==============================] - 23s 5ms/step - loss: 1.0481 - accuracy: 0.4925 - val_loss: 1.0445 - val_accuracy: 0.4947
# Epoch 15/100
# 4688/4688 [==============================] - 22s 5ms/step - loss: 1.0482 - accuracy: 0.4923 - val_loss: 1.0473 - val_accuracy: 0.4937
# Epoch 16/100
# 4688/4688 [==============================] - 22s 5ms/step - loss: 1.0481 - accuracy: 0.4924 - val_loss: 1.0458 - val_accuracy: 0.4920
# Epoch 17/100
# 4688/4688 [==============================] - 22s 5ms/step - loss: 1.0479 - accuracy: 0.4923 - val_loss: 1.0459 - val_accuracy: 0.4941
# Epoch 18/100
# 4688/4688 [==============================] - 21s 4ms/step - loss: 1.0479 - accuracy: 0.4927 - val_loss: 1.0454 - val_accuracy: 0.4940
# Epoch 19/100
# 4688/4688 [==============================] - 20s 4ms/step - loss: 1.0479 - accuracy: 0.4928 - val_loss: 1.0449 - val_accuracy: 0.4950
# Epoch 20/100
# 4688/4688 [==============================] - 21s 4ms/step - loss: 1.0477 - accuracy: 0.4926 - val_loss: 1.0448 - val_accuracy: 0.4944
# Epoch 21/100
# 4688/4688 [==============================] - 21s 4ms/step - loss: 1.0478 - accuracy: 0.4927 - val_loss: 1.0451 - val_accuracy: 0.4923
# Epoch 22/100
# 4688/4688 [==============================] - 20s 4ms/step - loss: 1.0479 - accuracy: 0.4926 - val_loss: 1.0448 - val_accuracy: 0.4950
# Epoch 23/100
# 4688/4688 [==============================] - 21s 5ms/step - loss: 1.0479 - accuracy: 0.4928 - val_loss: 1.0452 - val_accuracy: 0.4943
# Epoch 24/100
# 4688/4688 [==============================] - 22s 5ms/step - loss: 1.0478 - accuracy: 0.4927 - val_loss: 1.0452 - val_accuracy: 0.4933
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (None, 3, 64)             256
#
#  max_pooling1d_12 (MaxPoolin  (None, 3, 64)            0
#  g1D)
#
#  flatten_12 (Flatten)        (None, 192)               0
#
#  dense_24 (Dense)            (None, 128)               24704
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_25 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 25,605
# Trainable params: 25,605
# Non-trainable params: 0
# _________________________________________________________________
# 9375/9375 [==============================] - 11s 1ms/step - loss: 1.0445 - accuracy: 0.4947
# Test Loss: 1.0445433855056763
# Test Accuracy: 0.4946900010108948
