# %%
cd C:/Users/7-2009-1186-16/Desktop/-sampling-frequency-hz-/csv/5000hz/600rpm
# Out:
# C:\Users\7-2009-1186-16\Desktop\-sampling-frequency-hz-\csv\5000hz\600rpm

# %%
import pandas as pd

# 데이터 파일을 읽어옵니다.
normal_data = pd.read_csv("600rpm normal data/stream2024_4_22_23_33.csv")
carriage_data = pd.read_csv("600rpm carriage damage/stream2024_4_23_3_7.csv")
highspeed_data = pd.read_csv("600rpm high-speed damage/stream2024_4_23_0_30.csv")
lack_data = pd.read_csv("600rpm lack of lubrication/stream2024_4_23_2_17.csv")
corrosin = pd.read_csv("600rpm oxidation and corrosion/stream2024_4_23_1_26.csv")

# 데이터의 처음 몇 개 행을 확인하여 구조를 파악합니다.
print(carriage_data.head())

# 데이터 결측값 확인
missing_values = corrosin.isnull().sum()
print(missing_values)
# Out:
#    motor1_x  motor1_y  motor1_z     sound                         time
# 0  0.005416  0.000998  0.104189 -0.008152  2024-04-22T18:07:00.211375Z
# 1  0.013937  0.001314  0.023404 -0.007205  2024-04-22T18:07:00.211576Z
# 2  0.007941  0.000683  0.038551 -0.007205  2024-04-22T18:07:00.211776Z
# 3 -0.000895  0.000367  0.010781 -0.006889  2024-04-22T18:07:00.211975Z
# 4 -0.008152  0.000367 -0.033077  0.001630  2024-04-22T18:07:00.212175Z
# motor1_x    0
# motor1_y    0
# motor1_z    0
# sound       0
# time        0
# dtype: int64

# %%
# 데이터 시각화
import numpy as np
import pandas as pd
import random
import seaborn as sns
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# 데이터 파일을 읽어옵니다.
normal_data = pd.read_csv("600rpm normal data/stream2024_4_22_23_33.csv")
carriage_data = pd.read_csv("600rpm carriage damage/stream2024_4_23_3_7.csv")
highspeed_data = pd.read_csv("600rpm high-speed damage/stream2024_4_23_0_30.csv")
lack_data = pd.read_csv("600rpm lack of lubrication/stream2024_4_23_2_17.csv")
corrosin = pd.read_csv("600rpm oxidation and corrosion/stream2024_4_23_1_26.csv")

combined_data = pd.concat([normal_data, carriage_data, highspeed_data, lack_data, corrosin], ignore_index=True)

print(combined_data)

plt.figure(figsize=(15, 5))
plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(normal_data['motor1_y'], label='Y Axis')
#plt.plot(normal_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
plt.plot(combined_data['motor1_y'], label='Y Axis')
#plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['sound'], label='sound')
plt.title('Sound Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
# Out:
#          motor1_x  motor1_y  motor1_z     sound                         time
# 0        0.008888  0.000683  0.030346 -0.008152  2024-04-22T14:33:00.455179Z
# 1       -0.008467  0.000683 -0.040649 -0.006889  2024-04-22T14:33:00.455379Z
# 2        0.003207  0.000367 -0.016039 -0.005627  2024-04-22T14:33:00.455580Z
# 3        0.006679  0.000998 -0.079773  0.000998  2024-04-22T14:33:00.455779Z
# 4        0.006048  0.001314 -0.023927 -0.007836  2024-04-22T14:33:00.455979Z
# ...           ...       ...       ...       ...                          ...
# 1499995  0.004785  0.000367 -0.067468 -0.006258  2024-04-22T16:27:00.053602Z
# 1499996 -0.031815  0.000367  0.177400 -0.007836  2024-04-22T16:27:00.053802Z
# 1499997  0.014883  0.000998 -0.073147 -0.006574  2024-04-22T16:27:00.054002Z
# 1499998 -0.020772  0.000998 -0.077249 -0.008152  2024-04-22T16:27:00.054202Z
# 1499999  0.008572  0.000367  0.279644 -0.005943  2024-04-22T16:27:00.054402Z
#
# [1500000 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# 데이터 파일 로드
normal_data = pd.read_csv("600rpm normal data/stream2024_4_22_23_33.csv")
carriage_data = pd.read_csv("600rpm carriage damage/stream2024_4_23_3_7.csv")

# 정상 데이터에 레이블 0(정상) 할당, 비정상 데이터에 레이블 1(비정상) 할당
normal_data['label'] = 0
carriage_data['label'] = 1

# 데이터 결합
combined_data = pd.concat([normal_data, carriage_data], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z', 'sound']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=30)

# 1D CNN 입력을 위해 데이터 형태 변경
# (샘플 수, 시퀀스 길이, 채널 수)
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# CNN 모델 생성
model = Sequential()
model.add(Conv1D(64, kernel_size=4, activation='relu', input_shape=(X_train.shape[1], 1), padding='same'))
model.add(MaxPooling1D(pool_size=1))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))  # 이진 분류 출력 레이어

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Early stopping 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 훈련
history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_test, y_test), callbacks=[early_stopping])

# 모델 서머리
model.summary()

# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Epoch 1/100
# 3750/3750 [==============================] - 10s 2ms/step - loss: 0.6595 - accuracy: 0.5909 - val_loss: 0.6508 - val_accuracy: 0.5997
# Epoch 2/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6518 - accuracy: 0.6001 - val_loss: 0.6473 - val_accuracy: 0.6019
# Epoch 3/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6497 - accuracy: 0.6024 - val_loss: 0.6457 - val_accuracy: 0.6052
# Epoch 4/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6484 - accuracy: 0.6041 - val_loss: 0.6453 - val_accuracy: 0.6054
# Epoch 5/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6475 - accuracy: 0.6049 - val_loss: 0.6444 - val_accuracy: 0.6060
# Epoch 6/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6470 - accuracy: 0.6057 - val_loss: 0.6442 - val_accuracy: 0.6065
# Epoch 7/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6467 - accuracy: 0.6050 - val_loss: 0.6442 - val_accuracy: 0.6070
# Epoch 8/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6464 - accuracy: 0.6063 - val_loss: 0.6451 - val_accuracy: 0.6049
# Epoch 9/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6462 - accuracy: 0.6066 - val_loss: 0.6429 - val_accuracy: 0.6085
# Epoch 10/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6459 - accuracy: 0.6069 - val_loss: 0.6436 - val_accuracy: 0.6084
# Epoch 11/100
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.6457 - accuracy: 0.6073 - val_loss: 0.6426 - val_accuracy: 0.6087
# Epoch 12/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6454 - accuracy: 0.6077 - val_loss: 0.6425 - val_accuracy: 0.6085
# Epoch 13/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6452 - accuracy: 0.6071 - val_loss: 0.6422 - val_accuracy: 0.6084
# Epoch 14/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6451 - accuracy: 0.6083 - val_loss: 0.6414 - val_accuracy: 0.6092
# Epoch 15/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6449 - accuracy: 0.6077 - val_loss: 0.6419 - val_accuracy: 0.6085
# Epoch 16/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6447 - accuracy: 0.6075 - val_loss: 0.6418 - val_accuracy: 0.6097
# Epoch 17/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6445 - accuracy: 0.6087 - val_loss: 0.6416 - val_accuracy: 0.6098
# Epoch 18/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6443 - accuracy: 0.6083 - val_loss: 0.6415 - val_accuracy: 0.6103
# Epoch 19/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6443 - accuracy: 0.6087 - val_loss: 0.6417 - val_accuracy: 0.6094
# Epoch 20/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6441 - accuracy: 0.6094 - val_loss: 0.6414 - val_accuracy: 0.6090
# Epoch 21/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6441 - accuracy: 0.6085 - val_loss: 0.6422 - val_accuracy: 0.6083
# Epoch 22/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6440 - accuracy: 0.6088 - val_loss: 0.6409 - val_accuracy: 0.6097
# Epoch 23/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6440 - accuracy: 0.6088 - val_loss: 0.6416 - val_accuracy: 0.6116
# Epoch 24/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6436 - accuracy: 0.6098 - val_loss: 0.6413 - val_accuracy: 0.6086
# Epoch 25/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6437 - accuracy: 0.6099 - val_loss: 0.6405 - val_accuracy: 0.6108
# Epoch 26/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6437 - accuracy: 0.6092 - val_loss: 0.6408 - val_accuracy: 0.6100
# Epoch 27/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6435 - accuracy: 0.6095 - val_loss: 0.6415 - val_accuracy: 0.6117
# Epoch 28/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6434 - accuracy: 0.6094 - val_loss: 0.6404 - val_accuracy: 0.6111
# Epoch 29/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6432 - accuracy: 0.6096 - val_loss: 0.6411 - val_accuracy: 0.6102
# Epoch 30/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6432 - accuracy: 0.6103 - val_loss: 0.6405 - val_accuracy: 0.6105
# Epoch 31/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6431 - accuracy: 0.6101 - val_loss: 0.6411 - val_accuracy: 0.6096
# Epoch 32/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6432 - accuracy: 0.6096 - val_loss: 0.6407 - val_accuracy: 0.6105
# Epoch 33/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6431 - accuracy: 0.6102 - val_loss: 0.6408 - val_accuracy: 0.6104
# Epoch 34/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6429 - accuracy: 0.6100 - val_loss: 0.6404 - val_accuracy: 0.6089
# Epoch 35/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6429 - accuracy: 0.6112 - val_loss: 0.6405 - val_accuracy: 0.6100
# Epoch 36/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6429 - accuracy: 0.6106 - val_loss: 0.6404 - val_accuracy: 0.6107
# Epoch 37/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6428 - accuracy: 0.6103 - val_loss: 0.6405 - val_accuracy: 0.6111
# Epoch 38/100
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.6426 - accuracy: 0.6108 - val_loss: 0.6405 - val_accuracy: 0.6121
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 4, 64)             320
#
#  max_pooling1d (MaxPooling1D  (None, 4, 64)            0
#  )
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 50)                12850
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 13,221
# Trainable params: 13,221
# Non-trainable params: 0
# _________________________________________________________________
# 3750/3750 [==============================] - 4s 1ms/step - loss: 0.6404 - accuracy: 0.6111
# Test Loss: 0.640353262424469
# Test Accuracy: 0.6111416816711426

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import tensorflow as tf
import matplotlib.pyplot as plt

# GPU 설정
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) == 0:
    print("GPU가 없거나 설정되지 않았습니다. CPU로 계속 진행합니다.")
else:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# 데이터 파일 로드
# 각 고장 유형에 대한 데이터가 다른 폴더에 위치하는 경우를 가정
# 각 폴더에서 데이터를 로드하고 레이블을 할당한 후 데이터 결합

# 정상 데이터에 레이블 0(정상) 할당
normal_data = pd.read_csv("600rpm normal data/stream2024_4_22_23_33.csv")
normal_data['label'] = 'normal'

# 각 고장 유형에 대한 데이터를 로드하고 해당 레이블 할당
carriage_data = pd.read_csv("600rpm carriage damage/stream2024_4_23_3_7.csv")
carriage_data['label'] = 'carriage_data'

highspeed_data = pd.read_csv("600rpm high-speed damage/stream2024_4_23_0_30.csv")
highspeed_data['label'] = 'highspeed_data'

lack_data = pd.read_csv("600rpm lack of lubrication/stream2024_4_23_2_17.csv")
lack_data['label'] = 'lack_data'

corrosin = pd.read_csv("600rpm oxidation and corrosion/stream2024_4_23_1_26.csv")
corrosin['label'] = 'corrosin'

# 데이터 결합
combined_data = pd.concat([normal_data, carriage_data, highspeed_data, lack_data, corrosin], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z', 'sound']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 레이블 인코딩
encoder = LabelEncoder()
y = encoder.fit_transform(labels)
y = np_utils.to_categorical(y)  # 원-핫 인코딩

# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# 1D CNN 입력을 위해 데이터 형태 변경
# (샘플 수, 시퀀스 길이, 채널 수)
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# 모델 생성
model = Sequential()
model.add(Conv1D(64, kernel_size=4, activation='relu', input_shape=(X_train.shape[1], 1), padding='same'))
model.add(MaxPooling1D(pool_size=1))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5, activation='softmax'))  # 다중 클래스 분류

# 모델 컴파일
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Early stopping 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 훈련
history = model.fit(X_train, y_train, epochs=100, batch_size=256, validation_data=(X_test, y_test), callbacks=[early_stopping])



# 모델 서머리
model.summary()

# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# GPU가 없거나 설정되지 않았습니다. CPU로 계속 진행합니다.
# Epoch 1/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3411 - accuracy: 0.4130 - val_loss: 1.3280 - val_accuracy: 0.4189
# Epoch 2/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.3271 - accuracy: 0.4189 - val_loss: 1.3202 - val_accuracy: 0.4223
# Epoch 3/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.3244 - accuracy: 0.4204 - val_loss: 1.3202 - val_accuracy: 0.4215
# Epoch 4/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.3229 - accuracy: 0.4207 - val_loss: 1.3186 - val_accuracy: 0.4227
# Epoch 5/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.3221 - accuracy: 0.4214 - val_loss: 1.3161 - val_accuracy: 0.4240
# Epoch 6/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.3213 - accuracy: 0.4217 - val_loss: 1.3172 - val_accuracy: 0.4231
# Epoch 7/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3205 - accuracy: 0.4222 - val_loss: 1.3159 - val_accuracy: 0.4248
# Epoch 8/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3200 - accuracy: 0.4227 - val_loss: 1.3152 - val_accuracy: 0.4249
# Epoch 9/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3195 - accuracy: 0.4225 - val_loss: 1.3157 - val_accuracy: 0.4249
# Epoch 10/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3191 - accuracy: 0.4232 - val_loss: 1.3153 - val_accuracy: 0.4253
# Epoch 11/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.3186 - accuracy: 0.4230 - val_loss: 1.3140 - val_accuracy: 0.4248
# Epoch 12/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.3186 - accuracy: 0.4231 - val_loss: 1.3138 - val_accuracy: 0.4260
# Epoch 13/100
# 4688/4688 [==============================] - 13s 3ms/step - loss: 1.3184 - accuracy: 0.4232 - val_loss: 1.3139 - val_accuracy: 0.4255
# Epoch 14/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3179 - accuracy: 0.4232 - val_loss: 1.3138 - val_accuracy: 0.4256
# Epoch 15/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3178 - accuracy: 0.4234 - val_loss: 1.3134 - val_accuracy: 0.4257
# Epoch 16/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3175 - accuracy: 0.4235 - val_loss: 1.3128 - val_accuracy: 0.4252
# Epoch 17/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3172 - accuracy: 0.4239 - val_loss: 1.3129 - val_accuracy: 0.4262
# Epoch 18/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3172 - accuracy: 0.4237 - val_loss: 1.3122 - val_accuracy: 0.4255
# Epoch 19/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3171 - accuracy: 0.4236 - val_loss: 1.3123 - val_accuracy: 0.4261
# Epoch 20/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3170 - accuracy: 0.4238 - val_loss: 1.3128 - val_accuracy: 0.4260
# Epoch 21/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3168 - accuracy: 0.4241 - val_loss: 1.3131 - val_accuracy: 0.4260
# Epoch 22/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3168 - accuracy: 0.4239 - val_loss: 1.3123 - val_accuracy: 0.4258
# Epoch 23/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3166 - accuracy: 0.4241 - val_loss: 1.3132 - val_accuracy: 0.4247
# Epoch 24/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3165 - accuracy: 0.4242 - val_loss: 1.3122 - val_accuracy: 0.4256
# Epoch 25/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3164 - accuracy: 0.4241 - val_loss: 1.3133 - val_accuracy: 0.4253
# Epoch 26/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3162 - accuracy: 0.4245 - val_loss: 1.3132 - val_accuracy: 0.4252
# Epoch 27/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3162 - accuracy: 0.4242 - val_loss: 1.3121 - val_accuracy: 0.4265
# Epoch 28/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3161 - accuracy: 0.4242 - val_loss: 1.3122 - val_accuracy: 0.4260
# Epoch 29/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3160 - accuracy: 0.4242 - val_loss: 1.3131 - val_accuracy: 0.4253
# Epoch 30/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.3159 - accuracy: 0.4241 - val_loss: 1.3122 - val_accuracy: 0.4268
# Epoch 31/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3160 - accuracy: 0.4241 - val_loss: 1.3111 - val_accuracy: 0.4257
# Epoch 32/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3159 - accuracy: 0.4243 - val_loss: 1.3117 - val_accuracy: 0.4267
# Epoch 33/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3157 - accuracy: 0.4243 - val_loss: 1.3115 - val_accuracy: 0.4263
# Epoch 34/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3157 - accuracy: 0.4243 - val_loss: 1.3121 - val_accuracy: 0.4260
# Epoch 35/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.3155 - accuracy: 0.4242 - val_loss: 1.3121 - val_accuracy: 0.4258
# Epoch 36/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.3155 - accuracy: 0.4250 - val_loss: 1.3120 - val_accuracy: 0.4268
# Epoch 37/100
# 4688/4688 [==============================] - 14s 3ms/step - loss: 1.3155 - accuracy: 0.4247 - val_loss: 1.3112 - val_accuracy: 0.4265
# Epoch 38/100
# 4688/4688 [==============================] - 16s 3ms/step - loss: 1.3153 - accuracy: 0.4246 - val_loss: 1.3121 - val_accuracy: 0.4267
# Epoch 39/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.3155 - accuracy: 0.4249 - val_loss: 1.3114 - val_accuracy: 0.4260
# Epoch 40/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.3152 - accuracy: 0.4245 - val_loss: 1.3116 - val_accuracy: 0.4265
# Epoch 41/100
# 4688/4688 [==============================] - 15s 3ms/step - loss: 1.3153 - accuracy: 0.4246 - val_loss: 1.3131 - val_accuracy: 0.4263
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 4, 64)             320
#
#  max_pooling1d_1 (MaxPooling  (None, 4, 64)            0
#  1D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 33,861
# Trainable params: 33,861
# Non-trainable params: 0
# _________________________________________________________________
# 9375/9375 [==============================] - 11s 1ms/step - loss: 1.3111 - accuracy: 0.4257
# Test Loss: 1.3111201524734497
# Test Accuracy: 0.42568331956863403
