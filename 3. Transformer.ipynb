# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, MultiHeadAttention, LayerNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Flatten

# 데이터 파일 로드
normal_data = pd.read_csv('./csv/5000hz/300rpm/300rpm high-speed damage/stream2024_4_23_0_19.csv')
faulty_data = pd.read_csv('./csv/5000hz/300rpm/300rpm normal data/stream2024_4_22_23_19.csv')

# 정상 데이터에 레이블 0(정상) 할당, 비정상 데이터에 레이블 1(비정상) 할당
normal_data['label'] = 0
faulty_data['label'] = 1

# 데이터 결합
combined_data = pd.concat([normal_data, faulty_data], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=30)

# 1D CNN 입력을 위해 데이터 형태 변경
# (샘플 수, 시퀀스 길이, 채널 수)
X_train = np.expand_dims(X_train, axis=1)
X_test = np.expand_dims(X_test, axis=1)

# Transformer 블록
def transformer_block(x):
    attn_output = MultiHeadAttention(num_heads=5, key_dim=5)(x, x)
    attn_output = Dropout(0.1)(attn_output)
    out1 = LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn_output = Dense(out1.shape[-1], activation="relu")(out1)
    ffn_output = Dropout(0.1)(ffn_output)
    return LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

# 모델 구성
inputs = Input(shape=(1, 3))
x = transformer_block(inputs)
x = Flatten()(x)
x = Dense(50, activation="relu")(x)
outputs = Dense(1, activation="sigmoid")(x)
model = Model(inputs=inputs, outputs=outputs)

# 모델 컴파일 및 훈련
model.compile(optimizer=Adam(learning_rate=0.005), loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, batch_size=64, epochs=10, validation_data=(X_test, y_test))

# 결과 출력
print("Model summary:")
model.summary()

# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Epoch 1/10
# /Users/kimdozz0/Library/Python/3.9/lib/python/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (64, 5, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.6142 - loss: 0.6521 - val_accuracy: 0.6405 - val_loss: 0.6317
# Epoch 2/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6308 - loss: 0.6387 - val_accuracy: 0.6379 - val_loss: 0.6305
# Epoch 3/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6300 - loss: 0.6387 - val_accuracy: 0.6393 - val_loss: 0.6312
# Epoch 4/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6307 - loss: 0.6377 - val_accuracy: 0.6361 - val_loss: 0.6347
# Epoch 5/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6235 - loss: 0.6418 - val_accuracy: 0.6410 - val_loss: 0.6299
# Epoch 6/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6306 - loss: 0.6379 - val_accuracy: 0.6384 - val_loss: 0.6324
# Epoch 7/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6280 - loss: 0.6401 - val_accuracy: 0.6408 - val_loss: 0.6304
# Epoch 8/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6315 - loss: 0.6369 - val_accuracy: 0.6417 - val_loss: 0.6299
# Epoch 9/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6317 - loss: 0.6369 - val_accuracy: 0.6411 - val_loss: 0.6305
# Epoch 10/10
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6332 - loss: 0.6370 - val_accuracy: 0.6340 - val_loss: 0.6339
# Model summary:
# Model: "functional_41"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_26      │ (None, 1, 3)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 1, 3)      │        378 │ input_layer_26[0… │
# │ (MultiHeadAttentio… │                   │            │ input_layer_26[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_62          │ (None, 1, 3)      │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_52 (Add)        │ (None, 1, 3)      │          0 │ input_layer_26[0… │
# │                     │                   │            │ dropout_62[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 1, 3)      │          6 │ add_52[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_96 (Dense)    │ (None, 1, 3)      │         12 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_63          │ (None, 1, 3)      │          0 │ dense_96[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_53 (Add)        │ (None, 1, 3)      │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_63[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 1, 3)      │          6 │ add_53[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_20          │ (None, 3)         │          0 │ layer_normalizat… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_97 (Dense)    │ (None, 50)        │        200 │ flatten_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_98 (Dense)    │ (None, 1)         │         51 │ dense_97[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,961 (7.66 KB)
#  Trainable params: 653 (2.55 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,308 (5.11 KB)
#   90/3750 ━━━━━━━━━━━━━━━━━━━━ 2s 564us/step - accuracy: 0.6312 - loss: 0.6384
# /Users/kimdozz0/Library/Python/3.9/lib/python/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 5, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 2s 463us/step - accuracy: 0.6312 - loss: 0.6356
# Test Loss: 0.6338980197906494
# Test Accuracy: 0.633983314037323

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, LayerNormalization, MultiHeadAttention
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import matplotlib.pyplot as plt


# GPU 설정
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) == 0:
    print("GPU가 없거나 설정되지 않았습니다. CPU로 계속 진행합니다.")
else:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# 데이터 파일 로드
# 각 고장 유형에 대한 데이터가 다른 폴더에 위치하는 경우를 가정
# 각 폴더에서 데이터를 로드하고 레이블을 할당한 후 데이터 결합

# 정상 데이터에 레이블 0(정상) 할당
normal_data = pd.read_csv('./csv/5000hz/300rpm/300rpm normal data/stream2024_4_22_23_19.csv')
normal_data['label'] = 'normal'

# 각 고장 유형에 대한 데이터를 로드하고 해당 레이블 할당
faulty_data1 = pd.read_csv('./csv/5000hz/300rpm/300rpm high-speed damage/stream2024_4_23_0_19.csv')
faulty_data1['label'] = 'faulty_type_1'

faulty_data2 = pd.read_csv('./csv/5000hz/300rpm/300rpm oxidation and corrosion/stream2024_4_23_1_19.csv')
faulty_data2['label'] = 'faulty_type_2'

faulty_data3 = pd.read_csv('./csv/5000hz/300rpm/300rpm lack of lubrication/stream2024_4_23_2_11.csv')
faulty_data3['label'] = 'faulty_type_3'

faulty_data4 = pd.read_csv('./csv/5000hz/300rpm/300rpm carriage damage/stream2024_4_23_2_59.csv')
faulty_data4['label'] = 'faulty_type_4'

# 데이터 결합
combined_data = pd.concat([normal_data, faulty_data1, faulty_data2, faulty_data3, faulty_data4], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 레이블 인코딩
encoder = LabelEncoder()
y = encoder.fit_transform(labels)
Y_train = to_categorical(y)
num_classes = np.unique(y_train).size
print("Number of classes:", num_classes)
# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)
Y_train = to_categorical(y_train, num_classes=num_classes)
Y_test = to_categorical(y_test, num_classes=num_classes)

print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)

# Transformer 모델 구성
def transformer_encoder(inputs):
    # 멀티 헤드 어텐션 및 피드 포워드 네트워크
    attention = MultiHeadAttention(num_heads=2, key_dim=2)(inputs, inputs)
    x = LayerNormalization(epsilon=1e-6)(inputs + attention)
    x = Dense(64, activation='relu')(x)  # 출력 차원을 64로 조정
    ffn_output = Dense(64, activation='relu')(x)  # 출력 차원을 일치시킴
    ffn_output = Dropout(0.1)(ffn_output)
    return LayerNormalization(epsilon=1e-6)(x + ffn_output)

input_layer = Input(shape=(3,))
x = Dense(64, activation='relu')(input_layer)
x = transformer_encoder(x)
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
output_layer = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=input_layer, outputs=output_layer)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 학습
history = model.fit(X_train, Y_train, epochs=10, batch_size=32, validation_split=0.2)
print("Output layer configuration:", model.layers[-1].get_config())
# 평가
loss, accuracy = model.evaluate(X_test, Y_test)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")


# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, Y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# GPU가 없거나 설정되지 않았습니다. CPU로 계속 진행합니다.
# Number of classes: 5
# X_train shape: (1200000, 3)
# Y_train shape: (1200000, 5)
# X_test shape: (300000, 3)
# Y_test shape: (300000, 5)
# Epoch 1/10
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 90
#      87 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#      89 # 모델 학습
# ---> 90 history = model.fit(X_train, Y_train, epochs=10, batch_size=32, validation_split=0.2)
#      91 print("Output layer configuration:", model.layers[-1].get_config())
#      92 # 평가
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/layers/activations/softmax.py:66, in Softmax.call(self, inputs, mask)
#      59         return backend.numpy.exp(
#      60             inputs
#      61             - backend.math.logsumexp(
#      62                 inputs, axis=self.axis, keepdims=True
#      63             )
#      64         )
#      65     else:
# ---> 66         return activations.softmax(inputs, axis=self.axis[0])
#      67 return activations.softmax(inputs, axis=self.axis)
#
# IndexError: Exception encountered when calling Softmax.call().
#
# tuple index out of range
#
# Arguments received by Softmax.call():
#   • inputs=tf.Tensor(shape=(32, 2), dtype=float32)
#   • mask=None
