# %%
# 데이터 시각화
import numpy as np
import pandas as pd
import random
import seaborn as sns
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# 데이터 파일을 읽어옵니다.
normal_data = pd.read_csv("./csv/5000hz/300rpm/300rpm normal data/stream2024_4_22_23_19.csv")
carriage_data = pd.read_csv("./csv/5000hz/300rpm/300rpm carriage damage/stream2024_4_23_2_54.csv")
highspeed_data = pd.read_csv("./csv/5000hz/300rpm/300rpm high-speed damage/stream2024_4_23_0_20.csv")
lack_data = pd.read_csv("./csv/5000hz/300rpm/300rpm lack of lubrication/stream2024_4_23_2_6.csv")
corrosin = pd.read_csv("./csv/5000hz/300rpm/300rpm oxidation and corrosion/stream2024_4_23_1_16.csv")

combined_data = pd.concat([normal_data, carriage_data, highspeed_data, lack_data, corrosin], ignore_index=True)

print(combined_data)

plt.figure(figsize=(15, 5))
plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(normal_data['motor1_y'], label='Y Axis')
#plt.plot(normal_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
plt.plot(combined_data['motor1_y'], label='Y Axis')
#plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['sound'], label='sound')
plt.title('Sound Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
# Out:
#          motor1_x  motor1_y  motor1_z     sound                         time
# 0        0.004470  0.000683 -0.113217 -0.007836  2024-04-22T14:19:00.188683Z
# 1       -0.004681 -0.000264 -0.028029 -0.006258  2024-04-22T14:19:00.188883Z
# 2       -0.007521  0.000683  0.077050 -0.001526  2024-04-22T14:19:00.189083Z
# 3        0.010781  0.000683  0.099140 -0.007836  2024-04-22T14:19:00.189283Z
# 4        0.010465  0.000367 -0.045382 -0.008152  2024-04-22T14:19:00.189483Z
# ...           ...       ...       ...       ...                          ...
# 1499995  0.007941  0.000683 -0.076933 -0.005627  2024-04-22T16:17:00.405099Z
# 1499996 -0.007836  0.000367  0.036657 -0.006574  2024-04-22T16:17:00.405298Z
# 1499997  0.000998  0.000998  0.032555 -0.006574  2024-04-22T16:17:00.405499Z
# 1499998  0.010781  0.000683 -0.084821 -0.007836  2024-04-22T16:17:00.405699Z
# 1499999  0.002261  0.000998  0.025928 -0.005943  2024-04-22T16:17:00.405899Z
#
# [1500000 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Dropout, Input, Permute, Reshape, Multiply, Lambda, Concatenate
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import tensorflow as tf

# Attention 메커니즘 구현
def attention_layer(inputs, neurons):
    x = Permute((2, 1))(inputs)
    x = Dense(neurons, activation="softmax")(x)
    x = Permute((2, 1), name='attention_weights')(x)
    output = Multiply()([inputs, x])
    return output

# 데이터 파일 로드
normal_data = pd.read_csv("./csv/5000hz/300rpm/300rpm normal data/stream2024_4_22_23_19.csv")
carriage_data = pd.read_csv("./csv/5000hz/300rpm/300rpm carriage damage/stream2024_4_23_2_54.csv")

# 정상 데이터에 레이블 0(정상) 할당, 비정상 데이터에 레이블 1(비정상) 할당
normal_data['label'] = 0
carriage_data['label'] = 1

# 데이터 결합
combined_data = pd.concat([normal_data, carriage_data], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z', 'sound']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=30)

# LSTM 입력을 위해 데이터 형태 변경
# (샘플 수, 타임 스텝, 피쳐 수)
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# 모델 생성
inputs = Input(shape=(X_train.shape[1], X_train.shape[2]))
lstm_out = LSTM(64, return_sequences=True)(inputs)
attention_out = attention_layer(lstm_out, X_train.shape[1])

# Lambda 레이어에서 합 연산을 수행하고, output_shape를 명시적으로 정의합니다.
def sum_over_time(x):
    return tf.reduce_sum(x, axis=1)

attention_out = Lambda(sum_over_time, output_shape=(64,))(attention_out)
output = Dense(1, activation='sigmoid')(attention_out)
model = Model(inputs=[inputs], outputs=[output])

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Early stopping 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 훈련
history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_test, y_test), callbacks=[early_stopping])

# 모델 서머리
model.summary()

# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Epoch 1/100
# /Users/kimdozz0/Library/Python/3.9/lib/python/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (128, 64, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 3709/3750 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5767 - loss: 0.6668
# /Users/kimdozz0/Library/Python/3.9/lib/python/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over ax
100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.6197 - loss: 0.6333 - val_accuracy: 0.6211 - val_loss: 0.6337
# Epoch 94/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.6197 - loss: 0.6337 - val_accuracy: 0.6206 - val_loss: 0.6340
# Epoch 95/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.6189 - loss: 0.6342 - val_accuracy: 0.6191 - val_loss: 0.6341
# Epoch 96/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.6204 - loss: 0.6331 - val_accuracy: 0.6220 - val_loss: 0.6339
# Epoch 97/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6196 - loss: 0.6337 - val_accuracy: 0.6208 - val_loss: 0.6338
# Epoch 98/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6202 - loss: 0.6336 - val_accuracy: 0.6213 - val_loss: 0.6336
# Epoch 99/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.6203 - loss: 0.6329 - val_accuracy: 0.6208 - val_loss: 0.6339
# Epoch 100/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6214 - loss: 0.6321 - val_accuracy: 0.6205 - val_loss: 0.6340
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 1, 4)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_5 (LSTM)       │ (None, 1, 64)     │     17,664 │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_5 (Permute) │ (None, 64, 1)     │          0 │ lstm_5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 64, 1)     │          2 │ permute_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_weights   │ (None, 1, 64)     │          0 │ dense_8[0][0]     │
# │ (Permute)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 1, 64)     │          0 │ lstm_5[0][0],     │
# │ (Multiply)          │                   │            │ attention_weight… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 64)        │          0 │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1)         │         65 │ lambda_5[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 53,195 (207.80 KB)
#  Trainable params: 17,731 (69.26 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 35,464 (138.54 KB)
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 3s 797us/step - accuracy: 0.6211 - loss: 0.6339
# Test Loss: 0.6335696578025818
# Test Accuracy: 0.6212666630744934

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping
from tensorflow.python.keras.utils import np_utils
import tensorflow as tf
import matplotlib.pyplot as plt

# GPU 설정
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) == 0:
    print("GPU가 없거나 설정되지 않았습니다. CPU로 계속 진행합니다.")
else:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# Attention 메커니즘 구현
def attention_layer(inputs, neurons):
    x = Permute((2, 1))(inputs)
    x = Dense(neurons, activation="softmax")(x)
    x = Permute((2, 1))(x)
    output = Multiply()([inputs, x])
    return output

# 데이터 파일 로드
# 각 고장 유형에 대한 데이터가 다른 폴더에 위치하는 경우를 가정
# 각 폴더에서 데이터를 로드하고 레이블을 할당한 후 데이터 결합

# 정상 데이터에 레이블 0(정상) 할당
normal_data = pd.read_csv("./csv/5000hz/300rpm/300rpm normal data/stream2024_4_22_23_19.csv")
normal_data['label'] = 'normal'

# 각 고장 유형에 대한 데이터를 로드하고 해당 레이블 할당
carriage_data = pd.read_csv("./csv/5000hz/300rpm/300rpm carriage damage/stream2024_4_23_2_54.csv")
carriage_data['label'] = 'carriage_data'

highspeed_data = pd.read_csv("./csv/5000hz/300rpm/300rpm high-speed damage/stream2024_4_23_0_20.csv")
highspeed_data['label'] = 'highspeed_data'

lack_data = pd.read_csv("./csv/5000hz/300rpm/300rpm lack of lubrication/stream2024_4_23_2_6.csv")
lack_data['label'] = 'lack_data'

corrosin = pd.read_csv("./csv/5000hz/300rpm/300rpm oxidation and corrosion/stream2024_4_23_1_16.csv")
corrosin['label'] = 'corrosin'

# 데이터 결합
combined_data = pd.concat([normal_data, carriage_data, highspeed_data, lack_data, corrosin], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z', 'sound']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 레이블 인코딩
encoder = LabelEncoder()
y = encoder.fit_transform(labels)
y = np_utils.to_categorical(y)  # 원-핫 인코딩

# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# LSTM 입력을 위해 데이터 형태 변경
# (샘플 수, 타임 스텝, 피쳐 수)
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# 모델 생성
inputs = Input(shape=(X_train.shape[1], X_train.shape[2]))
lstm_out = LSTM(64, return_sequences=True)(inputs)
attention_out = attention_layer(lstm_out, 1)  # Attention layer 추가

# Attention 결과를 시퀀스 전체에 대해 합산
def sum_over_time(x):
    return tf.reduce_sum(x, axis=1)

attention_out = Lambda(sum_over_time, output_shape=(64,))(attention_out)
output = Dense(y_train.shape[1], activation='softmax')(attention_out)
model = Model(inputs=[inputs], outputs=[output])
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Early stopping 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 훈련
history = model.fit(X_train, y_train, epochs=100, batch_size=256, validation_data=(X_test, y_test), callbacks=[early_stopping])

# 모델 서머리
model.summary()

# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# GPU가 없거나 설정되지 않았습니다. CPU로 계속 진행합니다.
# Epoch 1/100
# /Users/kimdozz0/Library/Python/3.9/lib/python/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 64, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.3123 - loss: 1.5228 - val_accuracy: 0.3387 - val_loss: 1.4891
# Epoch 2/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3414 - loss: 1.4863 - val_accuracy: 0.3426 - val_loss: 1.4824
# Epoch 3/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3448 - loss: 1.4802 - val_accuracy: 0.3470 - val_loss: 1.4780
# Epoch 4/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3469 - loss: 1.4772 - val_accuracy: 0.3486 - val_loss: 1.4749
# Epoch 5/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3483 - loss: 1.4746 - val_accuracy: 0.3496 - val_loss: 1.4731
# Epoch 6/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.3500 - loss: 1.4731 - val_accuracy: 0.3487 - val_loss: 1.4728
# Epoch 7/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.3504 - loss: 1.4716 - val_accuracy: 0.3503 - val_loss: 1.4710
# Epoch 8/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.3501 - loss: 1.4707 - val_accuracy: 0.3505 - val_loss: 1.4707
# Epoch 9/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3509 - loss: 1.4697 - val_accuracy: 0.3510 - val_loss: 1.4705
# Epoch 10/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.3520 - loss: 1.4690 - val_accuracy: 0.3513 - val_loss: 1.4698
# Epoch 11/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.3513 - loss: 1.4691 - val_accuracy: 0.3508 - val_loss: 1.4693
# Epoch 12/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.3508 - loss: 1.4691 - val_accuracy: 0.3522 - val_loss: 1.4688
# Epoch 13/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - accuracy: 0.3519 - loss: 1.4680 - val_accuracy: 0.3518 - val_loss: 1.4687
# Epoch 14/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.3523 - loss: 1.4679 - val_accuracy: 0.3519 - val_loss: 1.4686
# Epoch 15/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.3527 - loss: 1.4667 - val_accuracy: 0.3524 - val_loss: 1.4676
# Epoch 16/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3524 - loss: 1.4671 - val_accuracy: 0.3525 - val_loss: 1.4679
# Epoch 17/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3530 - loss: 1.4667 - val_accuracy: 0.3529 - val_loss: 1.4671
# Epoch 18/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3531 - loss: 1.4670 - val_accuracy: 0.3529 - val_loss: 1.4672
# Epoch 19/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3531 - loss: 1.4664 - val_accuracy: 0.3525 - val_loss: 1.4671
# Epoch 20/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.3536 - loss: 1.4664 - val_accuracy: 0.3531 - val_loss: 1.4664
# Epoch 21/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3541 - loss: 1.4658 - val_accuracy: 0.3536 - val_loss: 1.4665
# Epoch 22/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.3542 - loss: 1.4648 - val_accuracy: 0.3531 - val_loss: 1.4664
# Epoch 23/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.3538 - loss: 1.4657 - val_accuracy: 0.3532 - val_loss: 1.4662
# Epoch 24/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3545 - loss: 1.4655 - val_accuracy: 0.3543 - val_loss: 1.4662
# Epoch 25/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.3544 - loss: 1.4651 - val_accuracy: 0.3537 - val_loss: 1.4659
# Epoch 26/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.3549 - loss: 1.4644 - val_accuracy: 0.3536 - val_loss: 1.4658
# Epoch 27/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.3544 - loss: 1.4651 - val_accuracy: 0.3543 - val_loss: 1.4656
# Epoch 28/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.3553 - loss: 1.4640 - val_accuracy: 0.3538 - val_loss: 1.4655
# Epoch 29/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.3546 - loss: 1.4642 - val_accuracy: 0.3536 - val_loss: 1.4655
# Epoch 30/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.3547 - loss: 1.4648 - val_accuracy: 0.3536 - val_loss: 1.4655
# Epoch 31/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.3546 - loss: 1.4646 - val_accuracy: 0.3548 - val_loss: 1.4654
# Epoch 32/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.3555 - loss: 1.4636 - val_accuracy: 0.3545 - val_loss: 1.4648
# Epoch 33/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.3559 - loss: 1.4629 - val_accuracy: 0.3541 - val_loss: 1.4647
# Epoch 34/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.3555 - loss: 1.4635 - val_accuracy: 0.3539 - val_loss: 1.4648
# Epoch 35/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3551 - loss: 1.4631 - val_accuracy: 0.3540 - val_loss: 1.4648
# Epoch 36/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3558 - loss: 1.4629 - val_accuracy: 0.3547 - val_loss: 1.4648
# Epoch 37/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3553 - loss: 1.4636 - val_accuracy: 0.3544 - val_loss: 1.4646
# Epoch 38/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.3552 - loss: 1.4630 - val_accuracy: 0.3548 - val_loss: 1.4641
# Epoch 39/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.3555 - loss: 1.4624 - val_accuracy: 0.3541 - val_loss: 1.4648
# Epoch 40/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3560 - loss: 1.4631 - val_accuracy: 0.3547 - val_loss: 1.4647
# Epoch 41/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3557 - loss: 1.4628 - val_accuracy: 0.3543 - val_loss: 1.4640
# Epoch 42/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3569 - loss: 1.4627 - val_accuracy: 0.3550 - val_loss: 1.4642
# Epoch 43/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3560 - loss: 1.4626 - val_accuracy: 0.3546 - val_loss: 1.4641
# Epoch 44/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3558 - loss: 1.4629 - val_accuracy: 0.3548 - val_loss: 1.4641
# Epoch 45/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.3560 - loss: 1.4628 - val_accuracy: 0.3546 - val_loss: 1.4640
# Epoch 46/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3553 - loss: 1.4633 - val_accuracy: 0.3544 - val_loss: 1.4642
# Epoch 47/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3550 - loss: 1.4629 - val_accuracy: 0.3548 - val_loss: 1.4646
# Epoch 48/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3559 - loss: 1.4630 - val_accuracy: 0.3549 - val_loss: 1.4642
# Epoch 49/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3558 - loss: 1.4627 - val_accuracy: 0.3549 - val_loss: 1.4638
# Epoch 50/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3565 - loss: 1.4619 - val_accuracy: 0.3548 - val_loss: 1.4635
# Epoch 51/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3556 - loss: 1.4635 - val_accuracy: 0.3546 - val_loss: 1.4637
# Epoch 52/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3558 - loss: 1.4621 - val_accuracy: 0.3547 - val_loss: 1.4643
# Epoch 53/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3562 - loss: 1.4625 - val_accuracy: 0.3548 - val_loss: 1.4637
# Epoch 54/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3560 - loss: 1.4619 - val_accuracy: 0.3552 - val_loss: 1.4636
# Epoch 55/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3570 - loss: 1.4619 - val_accuracy: 0.3550 - val_loss: 1.4641
# Epoch 56/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3557 - loss: 1.4626 - val_accuracy: 0.3551 - val_loss: 1.4637
# Epoch 57/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3567 - loss: 1.4617 - val_accuracy: 0.3548 - val_loss: 1.4637
# Epoch 58/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3553 - loss: 1.4618 - val_accuracy: 0.3551 - val_loss: 1.4636
# Epoch 59/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3567 - loss: 1.4619 - val_accuracy: 0.3547 - val_loss: 1.4636
# Epoch 60/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3567 - loss: 1.4626 - val_accuracy: 0.3549 - val_loss: 1.4630
# Epoch 61/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3566 - loss: 1.4613 - val_accuracy: 0.3555 - val_loss: 1.4634
# Epoch 62/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3561 - loss: 1.4627 - val_accuracy: 0.3554 - val_loss: 1.4633
# Epoch 63/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3563 - loss: 1.4617 - val_accuracy: 0.3552 - val_loss: 1.4632
# Epoch 64/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3559 - loss: 1.4618 - val_accuracy: 0.3549 - val_loss: 1.4631
# Epoch 65/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3562 - loss: 1.4620 - val_accuracy: 0.3557 - val_loss: 1.4630
# Epoch 66/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3556 - loss: 1.4619 - val_accuracy: 0.3550 - val_loss: 1.4635
# Epoch 67/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3567 - loss: 1.4614 - val_accuracy: 0.3558 - val_loss: 1.4631
# Epoch 68/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3567 - loss: 1.4619 - val_accuracy: 0.3547 - val_loss: 1.4634
# Epoch 69/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3556 - loss: 1.4622 - val_accuracy: 0.3554 - val_loss: 1.4629
# Epoch 70/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3560 - loss: 1.4614 - val_accuracy: 0.3544 - val_loss: 1.4635
# Epoch 71/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3569 - loss: 1.4611 - val_accuracy: 0.3547 - val_loss: 1.4632
# Epoch 72/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3569 - loss: 1.4614 - val_accuracy: 0.3546 - val_loss: 1.4633
# Epoch 73/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3562 - loss: 1.4619 - val_accuracy: 0.3539 - val_loss: 1.4633
# Epoch 74/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3570 - loss: 1.4604 - val_accuracy: 0.3556 - val_loss: 1.4627
# Epoch 75/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3557 - loss: 1.4621 - val_accuracy: 0.3548 - val_loss: 1.4633
# Epoch 76/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3569 - loss: 1.4609 - val_accuracy: 0.3545 - val_loss: 1.4633
# Epoch 77/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3563 - loss: 1.4608 - val_accuracy: 0.3555 - val_loss: 1.4630
# Epoch 78/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3561 - loss: 1.4616 - val_accuracy: 0.3553 - val_loss: 1.4630
# Epoch 79/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3573 - loss: 1.4613 - val_accuracy: 0.3548 - val_loss: 1.4631
# Epoch 80/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3563 - loss: 1.4614 - val_accuracy: 0.3547 - val_loss: 1.4631
# Epoch 81/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3564 - loss: 1.4616 - val_accuracy: 0.3555 - val_loss: 1.4628
# Epoch 82/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3564 - loss: 1.4616 - val_accuracy: 0.3556 - val_loss: 1.4629
# Epoch 83/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3563 - loss: 1.4612 - val_accuracy: 0.3554 - val_loss: 1.4628
# Epoch 84/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3571 - loss: 1.4598 - val_accuracy: 0.3553 - val_loss: 1.4626
# Epoch 85/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3565 - loss: 1.4611 - val_accuracy: 0.3547 - val_loss: 1.4628
# Epoch 86/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3573 - loss: 1.4607 - val_accuracy: 0.3553 - val_loss: 1.4625
# Epoch 87/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3568 - loss: 1.4612 - val_accuracy: 0.3553 - val_loss: 1.4626
# Epoch 88/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3569 - loss: 1.4610 - val_accuracy: 0.3554 - val_loss: 1.4626
# Epoch 89/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3565 - loss: 1.4610 - val_accuracy: 0.3546 - val_loss: 1.4632
# Epoch 90/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3571 - loss: 1.4608 - val_accuracy: 0.3555 - val_loss: 1.4626
# Epoch 91/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3564 - loss: 1.4610 - val_accuracy: 0.3559 - val_loss: 1.4623
# Epoch 92/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3573 - loss: 1.4606 - val_accuracy: 0.3561 - val_loss: 1.4624
# Epoch 93/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3561 - loss: 1.4608 - val_accuracy: 0.3551 - val_loss: 1.4627
# Epoch 94/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3559 - loss: 1.4612 - val_accuracy: 0.3557 - val_loss: 1.4626
# Epoch 95/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3572 - loss: 1.4603 - val_accuracy: 0.3558 - val_loss: 1.4622
# Epoch 96/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3573 - loss: 1.4605 - val_accuracy: 0.3553 - val_loss: 1.4623
# Epoch 97/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3574 - loss: 1.4604 - val_accuracy: 0.3556 - val_loss: 1.4622
# Epoch 98/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3566 - loss: 1.4605 - val_accuracy: 0.3551 - val_loss: 1.4629
# Epoch 99/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3565 - loss: 1.4610 - val_accuracy: 0.3560 - val_loss: 1.4626
# Epoch 100/100
# 4688/4688 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.3566 - loss: 1.4612 - val_accuracy: 0.3556 - val_loss: 1.4623
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 1, 4)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_7 (LSTM)       │ (None, 1, 64)     │     17,664 │ input_layer_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_8 (Permute) │ (None, 64, 1)     │          0 │ lstm_7[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 64, 1)     │          2 │ permute_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_9 (Permute) │ (None, 1, 64)     │          0 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 1, 64)     │          0 │ lstm_7[0][0],     │
# │ (Multiply)          │                   │            │ permute_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 64)        │          0 │ multiply_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 5)         │        325 │ lambda_7[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 53,975 (210.84 KB)
#  Trainable params: 17,991 (70.28 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 35,984 (140.57 KB)
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 4s 444us/step - accuracy: 0.3576 - loss: 1.4610
# Test Loss: 1.4622225761413574
# Test Accuracy: 0.35578998923301697
