# %%
# 데이터 시각화
import numpy as np
import pandas as pd
import random
import seaborn as sns
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# 데이터 파일을 읽어옵니다.
normal_data = pd.read_csv("./csv/5000hz/300rpm/300rpm normal data/stream2024_4_22_23_19.csv")
carriage_data = pd.read_csv("./csv/5000hz/300rpm/300rpm carriage damage/stream2024_4_23_2_54.csv")
highspeed_data = pd.read_csv("./csv/5000hz/300rpm/300rpm high-speed damage/stream2024_4_23_0_20.csv")
lack_data = pd.read_csv("./csv/5000hz/300rpm/300rpm lack of lubrication/stream2024_4_23_2_6.csv")
corrosin = pd.read_csv("./csv/5000hz/300rpm/300rpm oxidation and corrosion/stream2024_4_23_1_16.csv")

combined_data = pd.concat([normal_data, carriage_data, highspeed_data, lack_data, corrosin], ignore_index=True)

print(combined_data)

plt.figure(figsize=(15, 5))
plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(normal_data['motor1_y'], label='Y Axis')
#plt.plot(normal_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
plt.plot(combined_data['motor1_y'], label='Y Axis')
#plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['motor1_z'], label='Z Axis')
plt.title('Vibration Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
#plt.plot(combined_data['motor1_x'], label='X Axis')
#plt.plot(combined_data['motor1_y'], label='Y Axis')
plt.plot(combined_data['sound'], label='sound')
plt.title('Sound Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
# Out:
#          motor1_x  motor1_y  motor1_z     sound                         time
# 0        0.004470  0.000683 -0.113217 -0.007836  2024-04-22T14:19:00.188683Z
# 1       -0.004681 -0.000264 -0.028029 -0.006258  2024-04-22T14:19:00.188883Z
# 2       -0.007521  0.000683  0.077050 -0.001526  2024-04-22T14:19:00.189083Z
# 3        0.010781  0.000683  0.099140 -0.007836  2024-04-22T14:19:00.189283Z
# 4        0.010465  0.000367 -0.045382 -0.008152  2024-04-22T14:19:00.189483Z
# ...           ...       ...       ...       ...                          ...
# 1499995  0.007941  0.000683 -0.076933 -0.005627  2024-04-22T16:17:00.405099Z
# 1499996 -0.007836  0.000367  0.036657 -0.006574  2024-04-22T16:17:00.405298Z
# 1499997  0.000998  0.000998  0.032555 -0.006574  2024-04-22T16:17:00.405499Z
# 1499998  0.010781  0.000683 -0.084821 -0.007836  2024-04-22T16:17:00.405699Z
# 1499999  0.002261  0.000998  0.025928 -0.005943  2024-04-22T16:17:00.405899Z
#
# [1500000 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Dropout, Input, Permute, Reshape, Multiply, Lambda, Concatenate
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import tensorflow as tf

# Attention 메커니즘 구현
def attention_layer(inputs, neurons):
    x = Permute((2, 1))(inputs)
    x = Dense(neurons, activation="softmax")(x)
    x = Permute((2, 1), name='attention_weights')(x)
    output = Multiply()([inputs, x])
    return output

# 데이터 파일 로드
normal_data = pd.read_csv("./csv/5000hz/300rpm/300rpm normal data/stream2024_4_22_23_19.csv")
carriage_data = pd.read_csv("./csv/5000hz/300rpm/300rpm lack of lubrication/stream2024_4_23_2_6.csv")

# 정상 데이터에 레이블 0(정상) 할당, 비정상 데이터에 레이블 1(비정상) 할당
normal_data['label'] = 0
carriage_data['label'] = 1

# 데이터 결합
combined_data = pd.concat([normal_data, carriage_data], ignore_index=True)

# X, Y, Z 축 데이터와 레이블 선택
features = combined_data[['motor1_x', 'motor1_y', 'motor1_z', 'sound']]
labels = combined_data['label']

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(features)

# 훈련/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=30)

# LSTM 입력을 위해 데이터 형태 변경
# (샘플 수, 타임 스텝, 피쳐 수)
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# 모델 생성
inputs = Input(shape=(X_train.shape[1], X_train.shape[2]))
lstm_out = LSTM(64, return_sequences=True)(inputs)
attention_out = attention_layer(lstm_out, X_train.shape[1])

# Lambda 레이어에서 합 연산을 수행하고, output_shape를 명시적으로 정의합니다.
def sum_over_time(x):
    return tf.reduce_sum(x, axis=1)

attention_out = Lambda(sum_over_time, output_shape=(64,))(attention_out)
output = Dense(1, activation='sigmoid')(attention_out)
model = Model(inputs=[inputs], outputs=[output])

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Early stopping 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 훈련
history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_test, y_test), callbacks=[early_stopping])

# 모델 서머리
model.summary()

# 훈련 과정에서의 손실과 정확도를 확인
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 훈련 및 검증 데이터에 대한 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 데이터에 대한 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# 모델을 평가
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Epoch 1/100
# /Users/kimdozz0/Library/Python/3.9/lib/python/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (128, 64, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 3747/3750 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5219 - loss: 0.6916
# /Users/kimdozz0/Library/Python/3.9/lib/python/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 64, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.5219 - loss: 0.6916 - val_accuracy: 0.5301 - val_loss: 0.6900
# Epoch 2/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.5325 - loss: 0.6896 - val_accuracy: 0.5391 - val_loss: 0.6884
# Epoch 3/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0
100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.5747 - loss: 0.6729 - val_accuracy: 0.5705 - val_loss: 0.6741
# Epoch 77/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.5749 - loss: 0.6723 - val_accuracy: 0.5720 - val_loss: 0.6737
# Epoch 78/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5739 - loss: 0.6729 - val_accuracy: 0.5728 - val_loss: 0.6739
# Epoch 79/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.5734 - loss: 0.6734 - val_accuracy: 0.5716 - val_loss: 0.6740
# Epoch 80/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.5746 - loss: 0.6725 - val_accuracy: 0.5711 - val_loss: 0.6741
# Epoch 81/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.5744 - loss: 0.6729 - val_accuracy: 0.5718 - val_loss: 0.6735
# Epoch 82/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.5741 - loss: 0.6726 - val_accuracy: 0.5720 - val_loss: 0.6737
# Epoch 83/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.5750 - loss: 0.6722 - val_accuracy: 0.5712 - val_loss: 0.6739
# Epoch 84/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5745 - loss: 0.6727 - val_accuracy: 0.5714 - val_loss: 0.6739
# Epoch 85/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5760 - loss: 0.6721 - val_accuracy: 0.5712 - val_loss: 0.6737
# Epoch 86/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5755 - loss: 0.6721 - val_accuracy: 0.5717 - val_loss: 0.6735
# Epoch 87/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5749 - loss: 0.6721 - val_accuracy: 0.5710 - val_loss: 0.6734
# Epoch 88/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5755 - loss: 0.6719 - val_accuracy: 0.5722 - val_loss: 0.6740
# Epoch 89/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5750 - loss: 0.6724 - val_accuracy: 0.5721 - val_loss: 0.6736
# Epoch 90/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5748 - loss: 0.6726 - val_accuracy: 0.5709 - val_loss: 0.6735
# Epoch 91/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5735 - loss: 0.6725 - val_accuracy: 0.5720 - val_loss: 0.6735
# Epoch 92/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5750 - loss: 0.6725 - val_accuracy: 0.5730 - val_loss: 0.6733
# Epoch 93/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5739 - loss: 0.6723 - val_accuracy: 0.5726 - val_loss: 0.6733
# Epoch 94/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5758 - loss: 0.6720 - val_accuracy: 0.5692 - val_loss: 0.6738
# Epoch 95/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5750 - loss: 0.6720 - val_accuracy: 0.5718 - val_loss: 0.6733
# Epoch 96/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5760 - loss: 0.6717 - val_accuracy: 0.5735 - val_loss: 0.6728
# Epoch 97/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5755 - loss: 0.6718 - val_accuracy: 0.5725 - val_loss: 0.6733
# Epoch 98/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5743 - loss: 0.6722 - val_accuracy: 0.5713 - val_loss: 0.6733
# Epoch 99/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5771 - loss: 0.6715 - val_accuracy: 0.5715 - val_loss: 0.6732
# Epoch 100/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5753 - loss: 0.6718 - val_accuracy: 0.5716 - val_loss: 0.6733
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1, 4)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 1, 64)     │     17,664 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute (Permute)   │ (None, 64, 1)     │          0 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64, 1)     │          2 │ permute[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_weights   │ (None, 1, 64)     │          0 │ dense[0][0]       │
# │ (Permute)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 1, 64)     │          0 │ lstm[0][0],       │
# │                     │                   │            │ attention_weight… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 64)        │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         65 │ lambda[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 53,195 (207.80 KB)
#  Trainable params: 17,731 (69.26 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 35,464 (138.54 KB)
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 3s 663us/step - accuracy: 0.5726 - loss: 0.6733
# Test Loss: 0.6728222370147705
# Test Accuracy: 0.5734500288963318
